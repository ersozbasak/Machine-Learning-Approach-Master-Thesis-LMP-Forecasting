# %% [markdown]
# <a href="https://colab.research.google.com/github/ersozbasak/Machine-Learning-Regression-Models/blob/master/22_23_GRU_New_Eng_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Giriş

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import gc
import sys
#mpl.rcParams['figure.figsize'] = (17, 5)
#mpl.rcParams['axes.grid'] = False
#sns.set_style("whitegrid")
from pandas import DataFrame , concat
from sklearn.metrics import mean_absolute_error , mean_squared_error
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from numpy import mean , concatenate
from math import sqrt
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation,Dropout
from numpy import array , hstack
from tensorflow import keras
import tensorflow as tf
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NEW_ENG_LMP
# Out:
# /content/drive/MyDrive/NEW_ENG_LMP

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/NEW_ENG_LMP/lmp_rt_final_NEW_ENG.csv',engine='python',encoding='utf-8')

# %%
df_1.head()
# Out:
#          Date Hour Ending  Location ID    Location Name Location Type  \
# 0  06/01/2022           1        46728  LD.2121A_T 34.5  NETWORK NODE
# 1  06/01/2022           2        46728  LD.2121A_T 34.5  NETWORK NODE
# 2  06/01/2022           3        46728  LD.2121A_T 34.5  NETWORK NODE
# 3  06/01/2022           4        46728  LD.2121A_T 34.5  NETWORK NODE
# 4  06/01/2022           5        46728  LD.2121A_T 34.5  NETWORK NODE
#
#    Locational Marginal Price  Energy Component  Congestion Component  \
# 0                      75.47             75.47                  1.26
# 1                      79.10             78.13                  1.51
# 2                      93.96             94.43                  0.13
# 3                     110.48            111.09                  0.00
# 4                     133.10            133.43                  0.00
#
#    Marginal Loss Component
# 0                    -1.26
# 1                    -0.54
# 2                    -0.60
# 3                    -0.61
# 4                    -0.33

# %%
columns_to_drop = ['Date', 'Location ID', 'Location Type', 'Energy Component', 'Congestion Component', 'Marginal Loss Component']
df_1.drop(columns=columns_to_drop, inplace=True)

# %%
df_1.head()
# Out:
#   Hour Ending    Location Name  Locational Marginal Price
# 0           1  LD.2121A_T 34.5                      75.47
# 1           2  LD.2121A_T 34.5                      79.10
# 2           3  LD.2121A_T 34.5                      93.96
# 3           4  LD.2121A_T 34.5                     110.48
# 4           5  LD.2121A_T 34.5                     133.10

# %%
columns_to_drop = ['Hour Ending']
df_1.drop(columns=columns_to_drop, inplace=True)

# %%
df_1.head()
# Out:
#      Location Name  Locational Marginal Price
# 0  LD.2121A_T 34.5                      75.47
# 1  LD.2121A_T 34.5                      79.10
# 2  LD.2121A_T 34.5                      93.96
# 3  LD.2121A_T 34.5                     110.48
# 4  LD.2121A_T 34.5                     133.10

# %%
# extract unique 'NODE' values for each dataframe
node1 = set(df_1['Location Name'].unique())

# %%
# filter dataframes to keep only common 'NODE' values
df_filtered = df_1[df_1['Location Name'].isin(node1)]

# %%
# concatenate the filtered dataframes
merged_df_1 = pd.concat([df_filtered])

# %%
merged_df_1.head()
# Out:
#      Location Name  Locational Marginal Price
# 0  LD.2121A_T 34.5                      75.47
# 1  LD.2121A_T 34.5                      79.10
# 2  LD.2121A_T 34.5                      93.96
# 3  LD.2121A_T 34.5                     110.48
# 4  LD.2121A_T 34.5                     133.10

# %%
# applying the method
count_nan = merged_df_1.isnull().sum()

# printing the number of values present
# in the column
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: Location Name                0
# Locational Marginal Price    0
# dtype: int64

# %%
# group the merged_df dataframe by the 'NODE' column
grouped_df = merged_df_1.groupby('Location Name')

# get the names of each group
group_names = grouped_df.groups.keys()

node_list = []

# iterate through the grouped dataframe, get each group by its name, and append it to the node_list
for key, item in grouped_df:
    node_df = grouped_df.get_group(key)
    node_list.append(node_df)

stacked_df = []

# iterate through the node_list, drop the 'NODE' column, stack the dataframe, and append it to the stacked_df
for i in node_list:
    i_drop = i.drop('Location Name', axis=1)
    s_df = i_drop.stack().reset_index(drop=True)
    stacked_df.append(s_df)

node_dfs = {}
df_list = []

# iterate through the group_names, create a dataframe for each node, and append it to the df_list
for i, node in enumerate(group_names):
    node_dfs[node] = pd.DataFrame(stacked_df[i], columns=[node])
    df_list.append(node_dfs[node])

# concatenate the dataframes in the df_list along the columns to get the final dataframe
df_1 = pd.concat(df_list, axis=1)

# %%
df_1
# Out:
#       HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0              75.98            75.47                 77.42
# 1              78.99            79.10                 80.18
# 2              93.71            93.96                 95.32
# 3             110.17           110.48                111.98
# 4             132.44           133.10                134.34
# ...              ...              ...                   ...
# 8779           59.33            58.52                 59.16
# 8780           39.41            38.30                 39.46
# 8781           41.52            40.17                 41.71
# 8782           35.68            34.64                 35.98
# 8783           36.26            35.69                 36.55
#
#       LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                    77.42           74.57            77.18            55.70
# 1                    80.18           78.27            80.05            50.49
# 2                    95.32           92.89            94.90            51.56
# 3                   111.98          108.83           111.46            49.55
# 4                   134.34          130.35           133.90            48.90
# ...                    ...             ...              ...              ...
# 8779                 59.16           44.63            60.14              NaN
# 8780                 39.46            1.61            40.04              NaN
# 8781                 41.71           37.06            42.19              NaN
# 8782                 35.98           33.85            36.24              NaN
# 8783                 36.55           35.56            36.79              NaN
#
#       LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  \
# 0               76.32                    77.10            75.84
# 1               79.47                    80.10            78.06
# 2               94.41                    95.01            92.73
# 3              111.07                   111.68           108.71
# 4              133.54                   134.27           130.04
# ...               ...                      ...              ...
# 8779            58.89                    60.15            57.66
# 8780            39.07                    39.98            38.54
# 8781            41.22                    42.12            40.78
# 8782            35.46                    36.20            35.01
# 8783            36.10                    36.78            35.36
#
#       LD.ASHFIELD23  UN.9DRAGONS115 BOIS
# 0             77.29                74.57
# 1             80.39                78.27
# 2             96.00                92.89
# 3            113.07               108.83
# 4            135.60               130.35
# ...             ...                  ...
# 8779          57.82                44.63
# 8780          38.67                 1.61
# 8781          41.05                37.06
# 8782          35.42                33.85
# 8783          35.87                35.56
#
# [8784 rows x 12 columns]

# %%
count_nan = df_1.isnull().sum()
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: HC.AYER    115                0
# LD.2121A_T 34.5               0
# LD.5CORNRS 13.2T1 LD          0
# LD.5CORNRS 13.2T2 LD          0
# LD.9DRAGONS115                0
# LD.ACUSHNET13.2               0
# LD.ALLINGS 13.8            1080
# LD.AMHERST 34.5               0
# LD.ANDREWSQ13.8110AC LD       0
# LD.ANSONIA 13.8               0
# LD.ASHFIELD23                 0
# UN.9DRAGONS115 BOIS           0
# dtype: int64

# %%
df_1.dropna(inplace=True)

# %%
df_1.head()
# Out:
#    HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0           75.98            75.47                 77.42
# 1           78.99            79.10                 80.18
# 2           93.71            93.96                 95.32
# 3          110.17           110.48                111.98
# 4          132.44           133.10                134.34
#
#    LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                 77.42           74.57            77.18            55.70
# 1                 80.18           78.27            80.05            50.49
# 2                 95.32           92.89            94.90            51.56
# 3                111.98          108.83           111.46            49.55
# 4                134.34          130.35           133.90            48.90
#
#    LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  LD.ASHFIELD23  \
# 0            76.32                    77.10            75.84          77.29
# 1            79.47                    80.10            78.06          80.39
# 2            94.41                    95.01            92.73          96.00
# 3           111.07                   111.68           108.71         113.07
# 4           133.54                   134.27           130.04         135.60
#
#    UN.9DRAGONS115 BOIS
# 0                74.57
# 1                78.27
# 2                92.89
# 3               108.83
# 4               130.35

# %%
count_nan = df_1.isnull().sum()
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: HC.AYER    115             0
# LD.2121A_T 34.5            0
# LD.5CORNRS 13.2T1 LD       0
# LD.5CORNRS 13.2T2 LD       0
# LD.9DRAGONS115             0
# LD.ACUSHNET13.2            0
# LD.ALLINGS 13.8            0
# LD.AMHERST 34.5            0
# LD.ANDREWSQ13.8110AC LD    0
# LD.ANSONIA 13.8            0
# LD.ASHFIELD23              0
# UN.9DRAGONS115 BOIS        0
# dtype: int64

# %% [markdown]
# # GRU

# %%
df = df_1
df
# Out:
#       HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0              75.98            75.47                 77.42
# 1              78.99            79.10                 80.18
# 2              93.71            93.96                 95.32
# 3             110.17           110.48                111.98
# 4             132.44           133.10                134.34
# ...              ...              ...                   ...
# 7699           34.48            33.03                 34.49
# 7700           41.98            40.15                 42.01
# 7701           28.43            27.29                 28.46
# 7702           22.97            22.11                 22.97
# 7703           25.12            24.47                 25.15
#
#       LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                    77.42           74.57            77.18            55.70
# 1                    80.18           78.27            80.05            50.49
# 2                    95.32           92.89            94.90            51.56
# 3                   111.98          108.83           111.46            49.55
# 4                   134.34          130.35           133.90            48.90
# ...                    ...             ...              ...              ...
# 7699                 34.49           31.36            34.42            59.00
# 7700                 42.01           38.12            41.90            39.55
# 7701                 28.46           26.14            28.36            41.83
# 7702                 22.97           21.32            22.92            35.92
# 7703                 25.15           23.57            25.09            36.30
#
#       LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  \
# 0               76.32                    77.10            75.84
# 1               79.47                    80.10            78.06
# 2               94.41                    95.01            92.73
# 3              111.07                   111.68           108.71
# 4              133.54                   134.27           130.04
# ...               ...                      ...              ...
# 7699            34.09                    34.34            35.44
# 7700            41.48                    41.79            43.31
# 7701            28.11                    28.31            29.28
# 7702            22.76                    22.93            23.53
# 7703            24.95                    25.13            25.60
#
#       LD.ASHFIELD23  UN.9DRAGONS115 BOIS
# 0             77.29                74.57
# 1             80.39                78.27
# 2             96.00                92.89
# 3            113.07               108.83
# 4            135.60               130.35
# ...             ...                  ...
# 7699          34.62                31.36
# 7700          42.24                38.12
# 7701          28.61                26.14
# 7702          23.11                21.32
# 7703          25.22                23.57
#
# [7704 rows x 12 columns]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

class GRUModel():
    def __init__(self, lookback, features, forecast):
        self.lookback = lookback
        self.features = features
        self.forecast = forecast

    def df(self, dataframe, lookback, features, forecast):
        df = dataframe.values
        # Create the X and y arrays
        self.X, self.y = [], []
        for i in range(self.lookback, len(df) - self.forecast):
            self.X.append(df[i - self.lookback:i])
            self.y.append(df[i:i + self.forecast, 0])  # USD feature

        # Reshape the X and y arrays
        self.X, self.y = np.array(self.X), np.array(self.y)
        self.X = np.reshape(self.X, (self.X.shape[0], self.X.shape[1], self.features))  # (batch_size, lookback, features)
        self.y = np.reshape(self.y, (self.y.shape[0], self.forecast))  # (batch_size, forecast)

        return self.X, self.y

    def create_model(self, l_rate, epoch, batchsize, x_train_data, y_train_data):
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=15,mode='min',restore_best_weights=True)

        gru_model = Sequential()
        gru_model.add(GRU(128, activation='relu', input_shape=(self.lookback, self.features)))
        # Add the Dense layer with 128 units
        #gru_model.add(Dense(units=128, activation='relu'))
        gru_model.add(Dense(units=64, activation='relu'))
        gru_model.add(Dense(units=64, activation='relu'))
        gru_model.add(Dense(units=self.forecast))

        opt = tf.optimizers.Adam(learning_rate=l_rate)
        gru_model.compile(
            loss=tf.losses.MeanSquaredError(),
            optimizer=opt,
            metrics=[tf.metrics.MeanAbsoluteError()]
        )

        gru_history = gru_model.fit(
            x_train_data,
            y_train_data,
            epochs=epoch,
            batch_size=batchsize,
            verbose=1,
            validation_split=0.2,
            shuffle=False,
            callbacks=[early_stopping]
        )

        return gru_history, gru_model

# %%
gru = GRUModel(lookback=11, features=12, forecast=1)

# %%
X_all, y_all = gru.df(dataframe=df, lookback=11, features=12, forecast=1)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3, random_state=123)

# %%
history, model = gru.create_model(l_rate=0.001, epoch=450, batchsize=64, x_train_data=X_train, y_train_data=y_train)
# Out:
# Epoch 1/450
# 68/68 [==============================] - 4s 25ms/step - loss: 1005.8289 - mean_absolute_error: 16.3978 - val_loss: 1701.3337 - val_mean_absolute_error: 11.8367
# Epoch 2/450
# 68/68 [==============================] - 1s 22ms/step - loss: 470.9279 - mean_absolute_error: 11.1569 - val_loss: 1712.3191 - val_mean_absolute_error: 11.7333
# Epoch 3/450
# 68/68 [==============================] - 1s 21ms/step - loss: 471.1904 - mean_absolute_error: 11.2334 - val_loss: 1671.5833 - val_mean_absolute_error: 11.5851
# Epoch 4/450
# 68/68 [==============================] - 1s 22ms/step - loss: 463.1175 - mean_absolute_error: 11.0862 - val_loss: 1634.8933 - val_mean_absolute_error: 11.5268
# Epoch 5/450
# 68/68 [==============================] - 1s 20ms/step - loss: 455.9816 - mean_absolute_error: 11.0059 - val_loss: 1581.0393 - val_mean_absolute_error: 11.4177
# Epoch 6/450
# 68/68 [==============================] - 2s 37ms/step - loss: 451.5832 - mean_absolute_error: 10.9033 - val_loss: 1568.4327 - val_mean_absolute_error: 11.5617
# Epoch 7/450
# 68/68 [==============================] - 3s 40ms/step - loss: 447.2511 - mean_absolute_error: 10.9350 - val_loss: 1530.6829 - val_mean_absolute_error: 11.6852
# Epoch 8/450
# 68/68 [==============================] - 1s 22ms/step - loss: 444.5692 - mean_absolute_error: 10.8713 - val_loss: 1558.7378 - val_mean_absolute_error: 11.6839
# Epoch 9/450
# 68/68 [==============================] - 1s 20ms/step - loss: 447.1277 - mean_absolute_error: 10.9855 - val_loss: 1563.1765 - val_mean_absolute_error: 12.0207
# Epoch 10/450
# 68/68 [==============================] - 2s 23ms/step - loss: 445.6696 - mean_absolute_error: 10.9162 - val_loss: 1471.3983 - val_mean_absolute_error: 12.1623
# Epoch 11/450
# 68/68 [==============================] - 2s 24ms/step - loss: 448.3474 - mean_absolute_error: 10.8973 - val_loss: 1513.2505 - val_mean_absolute_error: 11.6048
# Epoch 12/450
# 68/68 [==============================] - 1s 21ms/step - loss: 440.0489 - mean_absolute_error: 10.7906 - val_loss: 1484.5651 - val_mean_absolute_error: 11.8476
# Epoch 13/450
# 68/68 [==============================] - 2s 23ms/step - loss: 441.8814 - mean_absolute_error: 10.8958 - val_loss: 1518.9312 - val_mean_absolute_error: 11.7801
# Epoch 14/450
# 68/68 [==============================] - 2s 32ms/step - loss: 436.3757 - mean_absolute_error: 10.7586 - val_loss: 1494.4755 - val_mean_absolute_error: 11.7748
# Epoch 15/450
# 68/68 [==============================] - 3s 40ms/step - loss: 446.9475 - mean_absolute_error: 10.8744 - val_loss: 1514.0454 - val_mean_absolute_error: 12.2823
# Epoch 16/450
# 68/68 [==============================] - 2s 22ms/step - loss: 449.2164 - mean_absolute_error: 10.7530 - val_loss: 1600.4011 - val_mean_absolute_error: 11.8494
# Epoch 17/450
# 68/68 [==============================] - 1s 20ms/step - loss: 452.7845 - mean_absolute_error: 10.8896 - val_loss: 1517.6224 - val_mean_absolute_error: 11.5114
# Epoch 18/450
# 68/68 [==============================] - 1s 21ms/step - loss: 444.0682 - mean_absolute_error: 10.7695 - val_loss: 1530.7445 - val_mean_absolute_error: 11.4361
# Epoch 19/450
# 68/68 [==============================] - 1s 20ms/step - loss: 443.0253 - mean_absolute_error: 10.7647 - val_loss: 1538.7250 - val_mean_absolute_error: 11.3739
# Epoch 20/450
# 68/68 [==============================] - 1s 21ms/step - loss: 439.6830 - mean_absolute_error: 10.7268 - val_loss: 1545.1693 - val_mean_absolute_error: 11.3682
# Epoch 21/450
# 68/68 [==============================] - 2s 24ms/step - loss: 438.2821 - mean_absolute_error: 10.7209 - val_loss: 1542.8031 - val_mean_absolute_error: 11.3950
# Epoch 22/450
# 68/68 [==============================] - 2s 23ms/step - loss: 437.6645 - mean_absolute_error: 10.6868 - val_loss: 1528.1073 - val_mean_absolute_error: 11.4639
# Epoch 23/450
# 68/68 [==============================] - 3s 41ms/step - loss: 438.1331 - mean_absolute_error: 10.7479 - val_loss: 1517.9913 - val_mean_absolute_error: 11.4709
# Epoch 24/450
# 68/68 [==============================] - 2s 33ms/step - loss: 436.6465 - mean_absolute_error: 10.6852 - val_loss: 1523.8743 - val_mean_absolute_error: 11.3979
# Epoch 25/450
# 68/68 [==============================] - 1s 22ms/step - loss: 439.8145 - mean_absolute_error: 10.7524 - val_loss: 1517.2159 - val_mean_absolute_error: 11.6418

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='GRUs - Training loss', linewidth=1, color='green')
    plt.plot(epochs, val_loss, 'r', label='GRUs - Validation loss', linewidth=1, color='purple')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(history, 'Training and validation loss')
# Out:
# <ipython-input-103-6b695fe83fa3>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'b', label='GRUs - Training loss', linewidth=1, color='green')
# <ipython-input-103-6b695fe83fa3>:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'r', label='GRUs - Validation loss', linewidth=1, color='purple')

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 3))
y_pred_resized = y_pred[:, -1]
y_test_resized = y_test[:, -1]

plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs - New Eng 2022-2023 24-hour ahead predictions for '30' days")

hour = 24
n_day = 30
plot_day = hour * n_day
plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted', color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1, color='purple')

plt.legend()
plt.show()
# Out:
# 73/73 [==============================] - 1s 5ms/step

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 3))
y_pred_resized = y_pred[:, -1]
y_test_resized = y_test[:, -1]

plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs - New Eng 2022-2023 24-hour ahead predictions for '5' days")

hour = 24
n_day = 5
plot_day = hour * n_day
plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted', color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1, color='purple')

plt.legend()
plt.show()
# Out:
# 73/73 [==============================] - 0s 4ms/step

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 3))
y_pred_resized = y_pred[:, -1]
y_test_resized = y_test[:, -1]

plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs - New Eng 2022-2023 24-hour ahead predictions for '1' day")

hour = 24
n_day = 1
plot_day = hour * n_day
plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted', color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1, color='purple')

plt.legend()
plt.show()
# Out:
# 73/73 [==============================] - 0s 4ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs - New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 30 Günlük")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs - New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 5 Günlük")

hour= 24
n_day = 5
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs - New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 1 Günlük")

hour= 24
n_day = 1
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Assuming y_pred and y_test are numpy arrays
# Reshape y_pred to match the shape of y_test
y_pred_reshaped = y_pred.mean(axis=1)

# Perform the subtraction
errors = y_pred_reshaped - y_test.squeeze()

# Calculate metrics
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()
r2 = r2_score(y_test.squeeze(), y_pred_reshaped)

# Print or use the metrics as required
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 1739.1286135210453
# Root Mean Squared Error: 41.70286097525019
# Mean Absolute Error: 12.184228580957681
# R-squared: 0.5280060085919629
