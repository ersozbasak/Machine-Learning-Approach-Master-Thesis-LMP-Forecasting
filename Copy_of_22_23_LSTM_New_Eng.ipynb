# %% [markdown]
# <a href="https://colab.research.google.com/github/ersozbasak/Machine-Learning-Regression-Models/blob/master/Copy_of_22_23_LSTM_New_Eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import gc
import sys
#mpl.rcParams['figure.figsize'] = (17, 5)
#mpl.rcParams['axes.grid'] = False
#sns.set_style("whitegrid")
from pandas import DataFrame , concat
from sklearn.metrics import mean_absolute_error , mean_squared_error
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from numpy import mean , concatenate
from math import sqrt
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation,Dropout
from numpy import array , hstack
from tensorflow import keras
import tensorflow as tf
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/NEW_ENG_LMP
# Out:
# /content/drive/MyDrive/NEW_ENG_LMP

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/NEW_ENG_LMP/lmp_rt_final_NEW_ENG.csv',engine='python',encoding='utf-8')

# %%
df_1.head()
# Out:
#          Date Hour Ending  Location ID    Location Name Location Type  \
# 0  06/01/2022           1        46728  LD.2121A_T 34.5  NETWORK NODE
# 1  06/01/2022           2        46728  LD.2121A_T 34.5  NETWORK NODE
# 2  06/01/2022           3        46728  LD.2121A_T 34.5  NETWORK NODE
# 3  06/01/2022           4        46728  LD.2121A_T 34.5  NETWORK NODE
# 4  06/01/2022           5        46728  LD.2121A_T 34.5  NETWORK NODE
#
#    Locational Marginal Price  Energy Component  Congestion Component  \
# 0                      75.47             75.47                  1.26
# 1                      79.10             78.13                  1.51
# 2                      93.96             94.43                  0.13
# 3                     110.48            111.09                  0.00
# 4                     133.10            133.43                  0.00
#
#    Marginal Loss Component
# 0                    -1.26
# 1                    -0.54
# 2                    -0.60
# 3                    -0.61
# 4                    -0.33

# %%
columns_to_drop = ['Date', 'Location ID', 'Location Type', 'Energy Component', 'Congestion Component', 'Marginal Loss Component']
df_1.drop(columns=columns_to_drop, inplace=True)

# %%
df_1.head()
# Out:
#   Hour Ending    Location Name  Locational Marginal Price
# 0           1  LD.2121A_T 34.5                      75.47
# 1           2  LD.2121A_T 34.5                      79.10
# 2           3  LD.2121A_T 34.5                      93.96
# 3           4  LD.2121A_T 34.5                     110.48
# 4           5  LD.2121A_T 34.5                     133.10

# %%
columns_to_drop = ['Hour Ending']
df_1.drop(columns=columns_to_drop, inplace=True)

# %%
df_1.head()
# Out:
#      Location Name  Locational Marginal Price
# 0  LD.2121A_T 34.5                      75.47
# 1  LD.2121A_T 34.5                      79.10
# 2  LD.2121A_T 34.5                      93.96
# 3  LD.2121A_T 34.5                     110.48
# 4  LD.2121A_T 34.5                     133.10

# %%
# extract unique 'NODE' values for each dataframe
node1 = set(df_1['Location Name'].unique())

# %%
# filter dataframes to keep only common 'NODE' values
df_filtered = df_1[df_1['Location Name'].isin(node1)]

# %%
# concatenate the filtered dataframes
merged_df_1 = pd.concat([df_filtered])

# %%
merged_df_1.head()
# Out:
#      Location Name  Locational Marginal Price
# 0  LD.2121A_T 34.5                      75.47
# 1  LD.2121A_T 34.5                      79.10
# 2  LD.2121A_T 34.5                      93.96
# 3  LD.2121A_T 34.5                     110.48
# 4  LD.2121A_T 34.5                     133.10

# %%
# applying the method
count_nan = merged_df_1.isnull().sum()

# printing the number of values present
# in the column
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: Location Name                0
# Locational Marginal Price    0
# dtype: int64

# %%
# group the merged_df dataframe by the 'NODE' column
grouped_df = merged_df_1.groupby('Location Name')

# get the names of each group
group_names = grouped_df.groups.keys()

node_list = []

# iterate through the grouped dataframe, get each group by its name, and append it to the node_list
for key, item in grouped_df:
    node_df = grouped_df.get_group(key)
    node_list.append(node_df)

stacked_df = []

# iterate through the node_list, drop the 'NODE' column, stack the dataframe, and append it to the stacked_df
for i in node_list:
    i_drop = i.drop('Location Name', axis=1)
    s_df = i_drop.stack().reset_index(drop=True)
    stacked_df.append(s_df)

node_dfs = {}
df_list = []

# iterate through the group_names, create a dataframe for each node, and append it to the df_list
for i, node in enumerate(group_names):
    node_dfs[node] = pd.DataFrame(stacked_df[i], columns=[node])
    df_list.append(node_dfs[node])

# concatenate the dataframes in the df_list along the columns to get the final dataframe
df_1 = pd.concat(df_list, axis=1)

# %%
df_1
# Out:
#       HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0              75.98            75.47                 77.42
# 1              78.99            79.10                 80.18
# 2              93.71            93.96                 95.32
# 3             110.17           110.48                111.98
# 4             132.44           133.10                134.34
# ...              ...              ...                   ...
# 8779           59.33            58.52                 59.16
# 8780           39.41            38.30                 39.46
# 8781           41.52            40.17                 41.71
# 8782           35.68            34.64                 35.98
# 8783           36.26            35.69                 36.55
#
#       LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                    77.42           74.57            77.18            55.70
# 1                    80.18           78.27            80.05            50.49
# 2                    95.32           92.89            94.90            51.56
# 3                   111.98          108.83           111.46            49.55
# 4                   134.34          130.35           133.90            48.90
# ...                    ...             ...              ...              ...
# 8779                 59.16           44.63            60.14              NaN
# 8780                 39.46            1.61            40.04              NaN
# 8781                 41.71           37.06            42.19              NaN
# 8782                 35.98           33.85            36.24              NaN
# 8783                 36.55           35.56            36.79              NaN
#
#       LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  \
# 0               76.32                    77.10            75.84
# 1               79.47                    80.10            78.06
# 2               94.41                    95.01            92.73
# 3              111.07                   111.68           108.71
# 4              133.54                   134.27           130.04
# ...               ...                      ...              ...
# 8779            58.89                    60.15            57.66
# 8780            39.07                    39.98            38.54
# 8781            41.22                    42.12            40.78
# 8782            35.46                    36.20            35.01
# 8783            36.10                    36.78            35.36
#
#       LD.ASHFIELD23  UN.9DRAGONS115 BOIS
# 0             77.29                74.57
# 1             80.39                78.27
# 2             96.00                92.89
# 3            113.07               108.83
# 4            135.60               130.35
# ...             ...                  ...
# 8779          57.82                44.63
# 8780          38.67                 1.61
# 8781          41.05                37.06
# 8782          35.42                33.85
# 8783          35.87                35.56
#
# [8784 rows x 12 columns]

# %%
count_nan = df_1.isnull().sum()
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: HC.AYER    115                0
# LD.2121A_T 34.5               0
# LD.5CORNRS 13.2T1 LD          0
# LD.5CORNRS 13.2T2 LD          0
# LD.9DRAGONS115                0
# LD.ACUSHNET13.2               0
# LD.ALLINGS 13.8            1080
# LD.AMHERST 34.5               0
# LD.ANDREWSQ13.8110AC LD       0
# LD.ANSONIA 13.8               0
# LD.ASHFIELD23                 0
# UN.9DRAGONS115 BOIS           0
# dtype: int64

# %%
df_1.dropna(inplace=True)

# %%
df_1.head()
# Out:
#    HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0           75.98            75.47                 77.42
# 1           78.99            79.10                 80.18
# 2           93.71            93.96                 95.32
# 3          110.17           110.48                111.98
# 4          132.44           133.10                134.34
#
#    LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                 77.42           74.57            77.18            55.70
# 1                 80.18           78.27            80.05            50.49
# 2                 95.32           92.89            94.90            51.56
# 3                111.98          108.83           111.46            49.55
# 4                134.34          130.35           133.90            48.90
#
#    LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  LD.ASHFIELD23  \
# 0            76.32                    77.10            75.84          77.29
# 1            79.47                    80.10            78.06          80.39
# 2            94.41                    95.01            92.73          96.00
# 3           111.07                   111.68           108.71         113.07
# 4           133.54                   134.27           130.04         135.60
#
#    UN.9DRAGONS115 BOIS
# 0                74.57
# 1                78.27
# 2                92.89
# 3               108.83
# 4               130.35

# %%
count_nan = df_1.isnull().sum()
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: HC.AYER    115             0
# LD.2121A_T 34.5            0
# LD.5CORNRS 13.2T1 LD       0
# LD.5CORNRS 13.2T2 LD       0
# LD.9DRAGONS115             0
# LD.ACUSHNET13.2            0
# LD.ALLINGS 13.8            0
# LD.AMHERST 34.5            0
# LD.ANDREWSQ13.8110AC LD    0
# LD.ANSONIA 13.8            0
# LD.ASHFIELD23              0
# UN.9DRAGONS115 BOIS        0
# dtype: int64

# %% [markdown]
# ## LSTM Entegrasyon

# %%
df_1.head()
# Out:
#    HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0           75.98            75.47                 77.42
# 1           78.99            79.10                 80.18
# 2           93.71            93.96                 95.32
# 3          110.17           110.48                111.98
# 4          132.44           133.10                134.34
#
#    LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                 77.42           74.57            77.18            55.70
# 1                 80.18           78.27            80.05            50.49
# 2                 95.32           92.89            94.90            51.56
# 3                111.98          108.83           111.46            49.55
# 4                134.34          130.35           133.90            48.90
#
#    LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  LD.ASHFIELD23  \
# 0            76.32                    77.10            75.84          77.29
# 1            79.47                    80.10            78.06          80.39
# 2            94.41                    95.01            92.73          96.00
# 3           111.07                   111.68           108.71         113.07
# 4           133.54                   134.27           130.04         135.60
#
#    UN.9DRAGONS115 BOIS
# 0                74.57
# 1                78.27
# 2                92.89
# 3               108.83
# 4               130.35

# %%
df = df_1
df
# Out:
#       HC.AYER    115  LD.2121A_T 34.5  LD.5CORNRS 13.2T1 LD  \
# 0              75.98            75.47                 77.42
# 1              78.99            79.10                 80.18
# 2              93.71            93.96                 95.32
# 3             110.17           110.48                111.98
# 4             132.44           133.10                134.34
# ...              ...              ...                   ...
# 7699           34.48            33.03                 34.49
# 7700           41.98            40.15                 42.01
# 7701           28.43            27.29                 28.46
# 7702           22.97            22.11                 22.97
# 7703           25.12            24.47                 25.15
#
#       LD.5CORNRS 13.2T2 LD  LD.9DRAGONS115  LD.ACUSHNET13.2  LD.ALLINGS 13.8  \
# 0                    77.42           74.57            77.18            55.70
# 1                    80.18           78.27            80.05            50.49
# 2                    95.32           92.89            94.90            51.56
# 3                   111.98          108.83           111.46            49.55
# 4                   134.34          130.35           133.90            48.90
# ...                    ...             ...              ...              ...
# 7699                 34.49           31.36            34.42            59.00
# 7700                 42.01           38.12            41.90            39.55
# 7701                 28.46           26.14            28.36            41.83
# 7702                 22.97           21.32            22.92            35.92
# 7703                 25.15           23.57            25.09            36.30
#
#       LD.AMHERST 34.5  LD.ANDREWSQ13.8110AC LD  LD.ANSONIA 13.8  \
# 0               76.32                    77.10            75.84
# 1               79.47                    80.10            78.06
# 2               94.41                    95.01            92.73
# 3              111.07                   111.68           108.71
# 4              133.54                   134.27           130.04
# ...               ...                      ...              ...
# 7699            34.09                    34.34            35.44
# 7700            41.48                    41.79            43.31
# 7701            28.11                    28.31            29.28
# 7702            22.76                    22.93            23.53
# 7703            24.95                    25.13            25.60
#
#       LD.ASHFIELD23  UN.9DRAGONS115 BOIS
# 0             77.29                74.57
# 1             80.39                78.27
# 2             96.00                92.89
# 3            113.07               108.83
# 4            135.60               130.35
# ...             ...                  ...
# 7699          34.62                31.36
# 7700          42.24                38.12
# 7701          28.61                26.14
# 7702          23.11                21.32
# 7703          25.22                23.57
#
# [7704 rows x 12 columns]

# %%
class LSTM():
    def __init__(self, lookback, features, forecast):
        self.lookback = lookback
        self.features = features
        self.forecast = forecast


    def df_1(self, dataframe, lookback, features, forecast):
        df_1 = dataframe.values
        # Create the X and y arrays
        self.X, self.y = [], []
        for i in range(self.lookback, len(df_1) - self.forecast):
            self.X.append(df_1[i-self.lookback:i])
            self.y.append(df_1[i:i+self.forecast, 0]) # USD feature

      # Reshape the X and y arrays
        self.X, self.y = np.array(self.X), np.array(self.y)
        self.X = np.reshape(self.X, (self.X.shape[0], self.X.shape[1], self.features)) # (batch_size, lookback, features)
        self.y = np.reshape(self.y, (self.y.shape[0], self.forecast)) # (batch_size, forecast)

        return self.X, self.y

# %%
lstm = LSTM(lookback=11, features=12, forecast=1)

# %%
X_all, y_all = lstm.df_1(dataframe = df_1, lookback = 11, features = 12, forecast = 1)

# %%
X_all
# Out:
# array([[[ 75.98,  75.47,  77.42, ...,  75.84,  77.29,  74.57],
#         [ 78.99,  79.1 ,  80.18, ...,  78.06,  80.39,  78.27],
#         [ 93.71,  93.96,  95.32, ...,  92.73,  96.  ,  92.89],
#         ...,
#         [ 67.32,  70.02,  67.93, ...,  66.23,  67.93,  66.65],
#         [ 63.75,  66.07,  64.31, ...,  62.83,  64.31,  62.96],
#         [ 61.7 ,  63.33,  62.5 , ...,  61.23,  62.49,  60.  ]],
#
#        [[ 78.99,  79.1 ,  80.18, ...,  78.06,  80.39,  78.27],
#         [ 93.71,  93.96,  95.32, ...,  92.73,  96.  ,  92.89],
#         [110.17, 110.48, 111.98, ..., 108.71, 113.07, 108.83],
#         ...,
#         [ 63.75,  66.07,  64.31, ...,  62.83,  64.31,  62.96],
#         [ 61.7 ,  63.33,  62.5 , ...,  61.23,  62.49,  60.  ],
#         [ 64.52,  65.61,  65.45, ...,  64.25,  65.46,  61.81]],
#
#        [[ 93.71,  93.96,  95.32, ...,  92.73,  96.  ,  92.89],
#         [110.17, 110.48, 111.98, ..., 108.71, 113.07, 108.83],
#         [132.44, 133.1 , 134.34, ..., 130.04, 135.6 , 130.35],
#         ...,
#         [ 61.7 ,  63.33,  62.5 , ...,  61.23,  62.49,  60.  ],
#         [ 64.52,  65.61,  65.45, ...,  64.25,  65.46,  61.81],
#         [ 66.29,  66.99,  67.21, ...,  66.06,  67.2 ,  63.39]],
#
#        ...,
#
#        [[ 42.77,  41.81,  42.87, ...,  44.03,  43.16,  39.34],
#         [ 49.55,  48.53,  49.6 , ...,  50.93,  49.84,  45.87],
#         [ 45.44,  44.74,  45.45, ...,  46.6 ,  45.62,  42.73],
#         ...,
#         [ 25.72,  24.85,  25.71, ...,  26.23,  25.8 ,  23.49],
#         [ 28.26,  27.2 ,  28.22, ...,  28.88,  28.29,  25.88],
#         [ 34.48,  33.03,  34.49, ...,  35.44,  34.62,  31.36]],
#
#        [[ 49.55,  48.53,  49.6 , ...,  50.93,  49.84,  45.87],
#         [ 45.44,  44.74,  45.45, ...,  46.6 ,  45.62,  42.73],
#         [ 48.73,  47.6 ,  48.77, ...,  50.11,  48.94,  45.24],
#         ...,
#         [ 28.26,  27.2 ,  28.22, ...,  28.88,  28.29,  25.88],
#         [ 34.48,  33.03,  34.49, ...,  35.44,  34.62,  31.36],
#         [ 41.98,  40.15,  42.01, ...,  43.31,  42.24,  38.12]],
#
#        [[ 45.44,  44.74,  45.45, ...,  46.6 ,  45.62,  42.73],
#         [ 48.73,  47.6 ,  48.77, ...,  50.11,  48.94,  45.24],
#         [ 43.14,  41.75,  43.16, ...,  44.49,  43.38,  39.65],
#         ...,
#         [ 34.48,  33.03,  34.49, ...,  35.44,  34.62,  31.36],
#         [ 41.98,  40.15,  42.01, ...,  43.31,  42.24,  38.12],
#         [ 28.43,  27.29,  28.46, ...,  29.28,  28.61,  26.14]]])

# %%
y_all
# Out:
# array([[64.52],
#        [66.29],
#        [92.73],
#        ...,
#        [41.98],
#        [28.43],
#        [22.97]])

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3,random_state=123)

# %%
print(y_all.max())
print(X_all.max())
print(y_all.min())
print(X_all.min())

print(np.mean(y_all))
print(np.mean(X_all))
# Out:
# 2252.63
# 2283.78
# -85.82
# -87.34
# 68.26814222568903
# 67.33486435139224

# %%
print("X_train shape : {}".format(X_train.shape))
print("y_train shape : {}".format(y_train.shape))
print("X_test shape : {}".format(X_test.shape))
print("y_test shape : {}".format(y_test.shape))
# Out:
# X_train shape : (5384, 11, 12)
# y_train shape : (5384, 1)
# X_test shape : (2308, 11, 12)
# y_test shape : (2308, 1)

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
def create_model(l_rate, epoch, batchsize, x_train_data, y_train_data):

  #early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=15,mode='min', restore_best_weights=True)#ceed
  lstm_model = tf.keras.Sequential()
  #lstm_model.add(tf.keras.layers.LSTM(256,activation='relu',input_shape=(lstm.lookback, lstm.features),return_sequences=True))
  lstm_model.add(tf.keras.layers.LSTM(64,activation='relu',input_shape=(lstm.lookback, lstm.features),return_sequences=True))
  lstm_model.add(tf.keras.layers.LSTM(64,activation='relu',input_shape=(lstm.lookback, lstm.features),return_sequences=True))
  #lstm_model.add(tf.keras.layers.LSTM(64,activation='relu'))
  lstm_model.add(tf.keras.layers.Dense(units=lstm.forecast))

  opt = tf.optimizers.Adam(learning_rate=l_rate)
  lstm_model.compile(
    loss=tf.losses.MeanSquaredError(),
    optimizer=opt,
    metrics=[tf.metrics.MeanAbsoluteError()]
    )

  lstm_history = lstm_model.fit(x_train_data, y_train_data,
    epochs=epoch,
    batch_size = batchsize,
    verbose=1,
    validation_split = 0.2,
    shuffle=False
    #callbacks = [early_stopping]
    )

  return lstm_history, lstm_model

# %%
history, model = create_model(l_rate = 0.001, epoch = 400, batchsize = 128, x_train_data = X_train, y_train_data = y_train)
# Out:
# Epoch 1/400
# 34/34 [==============================] - 3s 42ms/step - loss: 4710.3232 - mean_absolute_error: 45.4599 - val_loss: 6906.6489 - val_mean_absolute_error: 36.5807
# Epoch 2/400
# 34/34 [==============================] - 1s 28ms/step - loss: 2931.4871 - mean_absolute_error: 32.7940 - val_loss: 5930.0205 - val_mean_absolute_error: 32.5494
# Epoch 3/400
# 34/34 [==============================] - 1s 27ms/step - loss: 2439.6504 - mean_absolute_error: 29.6158 - val_loss: 5447.8247 - val_mean_absolute_error: 29.1030
# Epoch 4/400
# 34/34 [==============================] - 1s 27ms/step - loss: 2181.8591 - mean_absolute_error: 26.7409 - val_loss: 5094.7583 - val_mean_absolute_error: 26.7745
# Epoch 5/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1978.5385 - mean_absolute_error: 25.3350 - val_loss: 4889.5923 - val_mean_absolute_error: 25.7977
# Epoch 6/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1966.6111 - mean_absolute_error: 25.0637 - val_loss: 4846.3711 - val_mean_absolute_error: 25.1331
# Epoch 7/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1814.0909 - mean_absolute_error: 23.7428 - val_loss: 5137.9966 - val_mean_absolute_error: 25.2016
# Epoch 8/400
# 34/34 [==============================] - 1s 31ms/step - loss: 2018.8430 - mean_absolute_error: 24.0215 - val_loss: 4773.2720 - val_mean_absolute_error: 24.0741
# Epoch 9/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1848.2281 - mean_absolute_error: 22.6869 - val_loss: 4911.0386 - val_mean_absolute_error: 23.4287
# Epoch 10/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1768.2876 - mean_absolute_error: 22.4878 - val_loss: 4619.9478 - val_mean_absolute_error: 23.3871
# Epoch 11/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1706.5339 - mean_absolute_error: 21.8307 - val_loss: 4552.1548 - val_mean_absolute_error: 22.5610
# Epoch 12/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1669.8174 - mean_absolute_error: 21.6007 - val_loss: 4595.9258 - val_mean_absolute_error: 23.0908
# Epoch 13/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1795.8060 - mean_absolute_error: 22.3184 - val_loss: 4652.0708 - val_mean_absolute_error: 23.9266
# Epoch 14/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1716.0604 - mean_absolute_error: 22.3965 - val_loss: 4802.7388 - val_mean_absolute_error: 23.6196
# Epoch 15/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1682.5870 - mean_absolute_error: 22.0342 - val_loss: 4572.8418 - val_mean_absolute_error: 23.7040
# Epoch 16/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1653.2463 - mean_absolute_error: 21.9053 - val_loss: 4602.7026 - val_mean_absolute_error: 23.0705
# Epoch 17/400
# 34/34 [==============================] - 1s 36ms/step - loss: 1635.5659 - mean_absolute_error: 21.6436 - val_loss: 4517.9614 - val_mean_absolute_error: 22.8050
# Epoch 18/400
# 34/34 [==============================] - 2s 49ms/step - loss: 1625.3187 - mean_absolute_error: 21.5030 - val_loss: 4511.2798 - val_mean_absolute_error: 23.3828
# Epoch 19/400
# 34/34 [==============================] - 1s 39ms/step - loss: 1623.2557 - mean_absolute_error: 21.6648 - val_loss: 4620.5273 - val_mean_absolute_error: 23.0502
# Epoch 20/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1719.2526 - mean_absolute_error: 22.0248 - val_loss: 4781.6934 - val_mean_absolute_error: 23.8699
# Epoch 21/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1788.6362 - mean_absolute_error: 22.8240 - val_loss: 6302.8472 - val_mean_absolute_error: 29.7811
# Epoch 22/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1968.7648 - mean_absolute_error: 24.3564 - val_loss: 4899.5854 - val_mean_absolute_error: 24.2731
# Epoch 23/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1947.2598 - mean_absolute_error: 24.2079 - val_loss: 5016.2549 - val_mean_absolute_error: 24.6562
# Epoch 24/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1972.9127 - mean_absolute_error: 24.2868 - val_loss: 4984.2227 - val_mean_absolute_error: 26.6475
# Epoch 25/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1870.8970 - mean_absolute_error: 24.1464 - val_loss: 4920.4043 - val_mean_absolute_error: 24.4206
# Epoch 26/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1771.8826 - mean_absolute_error: 22.9955 - val_loss: 4776.1440 - val_mean_absolute_error: 23.6802
# Epoch 27/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1691.9161 - mean_absolute_error: 22.2338 - val_loss: 4623.6914 - val_mean_absolute_error: 23.1666
# Epoch 28/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1654.9032 - mean_absolute_error: 21.9901 - val_loss: 4629.8169 - val_mean_absolute_error: 23.3503
# Epoch 29/400
# 34/34 [==============================] - 1s 40ms/step - loss: 1661.4836 - mean_absolute_error: 21.9258 - val_loss: 4569.3281 - val_mean_absolute_error: 22.9536
# Epoch 30/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1623.3671 - mean_absolute_error: 21.5957 - val_loss: 4476.6665 - val_mean_absolute_error: 22.5783
# Epoch 31/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1626.3644 - mean_absolute_error: 21.3557 - val_loss: 4471.7881 - val_mean_absolute_error: 22.3073
# Epoch 32/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1599.2217 - mean_absolute_error: 21.0588 - val_loss: 4496.7661 - val_mean_absolute_error: 22.5196
# Epoch 33/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1600.0677 - mean_absolute_error: 21.1328 - val_loss: 4504.1562 - val_mean_absolute_error: 22.4430
# Epoch 34/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1606.0035 - mean_absolute_error: 21.1374 - val_loss: 4496.9897 - val_mean_absolute_error: 22.0096
# Epoch 35/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1599.6969 - mean_absolute_error: 21.0282 - val_loss: 4448.0249 - val_mean_absolute_error: 21.7296
# Epoch 36/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1537.2314 - mean_absolute_error: 20.9035 - val_loss: 4407.3560 - val_mean_absolute_error: 22.2612
# Epoch 37/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1557.9976 - mean_absolute_error: 20.9113 - val_loss: 4452.9331 - val_mean_absolute_error: 21.9108
# Epoch 38/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1790.2069 - mean_absolute_error: 22.3074 - val_loss: 5141.0942 - val_mean_absolute_error: 24.2601
# Epoch 39/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1879.1301 - mean_absolute_error: 22.9861 - val_loss: 4875.4043 - val_mean_absolute_error: 24.8555
# Epoch 40/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1743.0394 - mean_absolute_error: 22.6326 - val_loss: 4519.6230 - val_mean_absolute_error: 23.1037
# Epoch 41/400
# 34/34 [==============================] - 1s 36ms/step - loss: 1600.9031 - mean_absolute_error: 21.3566 - val_loss: 4511.4331 - val_mean_absolute_error: 22.5997
# Epoch 42/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1600.4991 - mean_absolute_error: 21.2333 - val_loss: 4503.7915 - val_mean_absolute_error: 22.5647
# Epoch 43/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1579.8344 - mean_absolute_error: 21.4501 - val_loss: 4583.1558 - val_mean_absolute_error: 22.6938
# Epoch 44/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1597.2260 - mean_absolute_error: 21.2612 - val_loss: 4629.3867 - val_mean_absolute_error: 22.4929
# Epoch 45/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1578.8008 - mean_absolute_error: 21.0786 - val_loss: 4480.2017 - val_mean_absolute_error: 22.0518
# Epoch 46/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1605.6538 - mean_absolute_error: 20.7182 - val_loss: 4493.9854 - val_mean_absolute_error: 22.2553
# Epoch 47/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1533.0615 - mean_absolute_error: 20.6388 - val_loss: 4433.3989 - val_mean_absolute_error: 21.9892
# Epoch 48/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1557.5084 - mean_absolute_error: 20.6838 - val_loss: 4470.2148 - val_mean_absolute_error: 22.0274
# Epoch 49/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1530.4470 - mean_absolute_error: 20.6381 - val_loss: 4514.1738 - val_mean_absolute_error: 21.8443
# Epoch 50/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1517.4789 - mean_absolute_error: 20.6609 - val_loss: 4519.4292 - val_mean_absolute_error: 21.5912
# Epoch 51/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1512.9636 - mean_absolute_error: 20.5586 - val_loss: 4508.9766 - val_mean_absolute_error: 21.7737
# Epoch 52/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1503.0238 - mean_absolute_error: 20.6159 - val_loss: 4514.0620 - val_mean_absolute_error: 21.7785
# Epoch 53/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1494.5486 - mean_absolute_error: 20.4626 - val_loss: 4510.1777 - val_mean_absolute_error: 21.6754
# Epoch 54/400
# 34/34 [==============================] - 2s 50ms/step - loss: 1477.6409 - mean_absolute_error: 20.3483 - val_loss: 4480.1704 - val_mean_absolute_error: 21.7181
# Epoch 55/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1470.9839 - mean_absolute_error: 20.3555 - val_loss: 4465.8813 - val_mean_absolute_error: 21.5987
# Epoch 56/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1476.6531 - mean_absolute_error: 20.3785 - val_loss: 4484.7354 - val_mean_absolute_error: 21.6697
# Epoch 57/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1462.8564 - mean_absolute_error: 20.3294 - val_loss: 4477.1211 - val_mean_absolute_error: 21.3861
# Epoch 58/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1465.5427 - mean_absolute_error: 20.2903 - val_loss: 4434.9160 - val_mean_absolute_error: 21.6525
# Epoch 59/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1456.6650 - mean_absolute_error: 20.2951 - val_loss: 4430.3862 - val_mean_absolute_error: 21.6096
# Epoch 60/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1449.7588 - mean_absolute_error: 20.2509 - val_loss: 4438.6084 - val_mean_absolute_error: 21.3317
# Epoch 61/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1444.2297 - mean_absolute_error: 20.1376 - val_loss: 4430.3599 - val_mean_absolute_error: 21.4620
# Epoch 62/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1446.8015 - mean_absolute_error: 20.2613 - val_loss: 4475.4077 - val_mean_absolute_error: 21.5177
# Epoch 63/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1451.8865 - mean_absolute_error: 20.1284 - val_loss: 4433.0757 - val_mean_absolute_error: 21.3299
# Epoch 64/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1470.0941 - mean_absolute_error: 20.4320 - val_loss: 4558.2036 - val_mean_absolute_error: 21.6910
# Epoch 65/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1494.5945 - mean_absolute_error: 20.6456 - val_loss: 4518.4277 - val_mean_absolute_error: 21.3837
# Epoch 66/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1475.3958 - mean_absolute_error: 20.6632 - val_loss: 4418.3823 - val_mean_absolute_error: 21.7848
# Epoch 67/400
# 34/34 [==============================] - 1s 39ms/step - loss: 1456.3429 - mean_absolute_error: 20.3951 - val_loss: 4403.2324 - val_mean_absolute_error: 21.6358
# Epoch 68/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1445.0891 - mean_absolute_error: 20.3567 - val_loss: 4463.3853 - val_mean_absolute_error: 21.5943
# Epoch 69/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1476.9622 - mean_absolute_error: 20.5262 - val_loss: 4538.5034 - val_mean_absolute_error: 21.7773
# Epoch 70/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1483.2130 - mean_absolute_error: 20.6719 - val_loss: 4484.4873 - val_mean_absolute_error: 22.0496
# Epoch 71/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1455.7861 - mean_absolute_error: 20.4105 - val_loss: 4435.0220 - val_mean_absolute_error: 21.3953
# Epoch 72/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1434.2767 - mean_absolute_error: 20.1618 - val_loss: 4458.4956 - val_mean_absolute_error: 20.9508
# Epoch 73/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1437.8030 - mean_absolute_error: 20.1732 - val_loss: 4434.8643 - val_mean_absolute_error: 21.4376
# Epoch 74/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1445.3208 - mean_absolute_error: 20.2815 - val_loss: 4493.9614 - val_mean_absolute_error: 21.9291
# Epoch 75/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1453.7515 - mean_absolute_error: 20.3300 - val_loss: 4464.2417 - val_mean_absolute_error: 21.4004
# Epoch 76/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1422.9114 - mean_absolute_error: 20.3412 - val_loss: 4461.1270 - val_mean_absolute_error: 21.4125
# Epoch 77/400
# 34/34 [==============================] - 2s 46ms/step - loss: 1423.6503 - mean_absolute_error: 20.2780 - val_loss: 4484.9966 - val_mean_absolute_error: 21.1534
# Epoch 78/400
# 34/34 [==============================] - 2s 50ms/step - loss: 1405.5756 - mean_absolute_error: 20.0537 - val_loss: 4471.2720 - val_mean_absolute_error: 21.4148
# Epoch 79/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1411.9890 - mean_absolute_error: 20.0838 - val_loss: 4435.0259 - val_mean_absolute_error: 21.3041
# Epoch 80/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1401.4805 - mean_absolute_error: 20.1186 - val_loss: 4460.4116 - val_mean_absolute_error: 21.2602
# Epoch 81/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1432.9023 - mean_absolute_error: 20.1998 - val_loss: 4465.4951 - val_mean_absolute_error: 21.2215
# Epoch 82/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1410.0673 - mean_absolute_error: 20.1747 - val_loss: 4343.7124 - val_mean_absolute_error: 21.2611
# Epoch 83/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1420.7471 - mean_absolute_error: 20.3936 - val_loss: 4471.6147 - val_mean_absolute_error: 21.4086
# Epoch 84/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1424.4619 - mean_absolute_error: 20.3876 - val_loss: 4418.8496 - val_mean_absolute_error: 21.4635
# Epoch 85/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1420.4700 - mean_absolute_error: 20.1987 - val_loss: 4391.3613 - val_mean_absolute_error: 21.2729
# Epoch 86/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1434.1500 - mean_absolute_error: 20.3396 - val_loss: 4435.0640 - val_mean_absolute_error: 21.2907
# Epoch 87/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1412.4600 - mean_absolute_error: 20.3687 - val_loss: 4400.8320 - val_mean_absolute_error: 21.0601
# Epoch 88/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1404.6879 - mean_absolute_error: 20.1810 - val_loss: 4573.6304 - val_mean_absolute_error: 21.6689
# Epoch 89/400
# 34/34 [==============================] - 2s 46ms/step - loss: 1418.6085 - mean_absolute_error: 20.3287 - val_loss: 4465.6562 - val_mean_absolute_error: 21.9539
# Epoch 90/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1456.9849 - mean_absolute_error: 20.6784 - val_loss: 4707.2690 - val_mean_absolute_error: 22.0781
# Epoch 91/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1460.8088 - mean_absolute_error: 20.4517 - val_loss: 4402.2441 - val_mean_absolute_error: 21.6544
# Epoch 92/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1435.8079 - mean_absolute_error: 20.4555 - val_loss: 4468.5718 - val_mean_absolute_error: 21.6324
# Epoch 93/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1419.4952 - mean_absolute_error: 20.2395 - val_loss: 4439.7729 - val_mean_absolute_error: 21.3466
# Epoch 94/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1406.3016 - mean_absolute_error: 20.1579 - val_loss: 4498.6797 - val_mean_absolute_error: 21.2901
# Epoch 95/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1394.3494 - mean_absolute_error: 20.1131 - val_loss: 4408.9175 - val_mean_absolute_error: 21.5408
# Epoch 96/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1390.5585 - mean_absolute_error: 20.0397 - val_loss: 4399.3506 - val_mean_absolute_error: 21.2004
# Epoch 97/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1405.3740 - mean_absolute_error: 20.0864 - val_loss: 4433.2593 - val_mean_absolute_error: 21.4964
# Epoch 98/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1397.3568 - mean_absolute_error: 20.0568 - val_loss: 4419.7852 - val_mean_absolute_error: 21.3805
# Epoch 99/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1379.3827 - mean_absolute_error: 20.0035 - val_loss: 4410.2290 - val_mean_absolute_error: 21.4476
# Epoch 100/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1385.0859 - mean_absolute_error: 19.9498 - val_loss: 4408.3560 - val_mean_absolute_error: 21.9999
# Epoch 101/400
# 34/34 [==============================] - 2s 49ms/step - loss: 1374.6072 - mean_absolute_error: 19.9479 - val_loss: 4402.8677 - val_mean_absolute_error: 21.7856
# Epoch 102/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1383.5670 - mean_absolute_error: 19.9604 - val_loss: 4393.5249 - val_mean_absolute_error: 21.5092
# Epoch 103/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1366.2272 - mean_absolute_error: 19.8662 - val_loss: 4414.0830 - val_mean_absolute_error: 21.1248
# Epoch 104/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1382.6367 - mean_absolute_error: 19.8303 - val_loss: 4388.6733 - val_mean_absolute_error: 21.3850
# Epoch 105/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1378.0148 - mean_absolute_error: 19.9653 - val_loss: 4367.7515 - val_mean_absolute_error: 21.1856
# Epoch 106/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1403.8264 - mean_absolute_error: 20.0657 - val_loss: 4475.1348 - val_mean_absolute_error: 21.3495
# Epoch 107/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1391.5558 - mean_absolute_error: 20.0137 - val_loss: 4421.7573 - val_mean_absolute_error: 21.1032
# Epoch 108/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1387.3837 - mean_absolute_error: 19.9682 - val_loss: 4467.5811 - val_mean_absolute_error: 21.4853
# Epoch 109/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1395.8195 - mean_absolute_error: 20.0835 - val_loss: 4405.3804 - val_mean_absolute_error: 20.9806
# Epoch 110/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1374.2931 - mean_absolute_error: 19.8268 - val_loss: 4470.0801 - val_mean_absolute_error: 21.4281
# Epoch 111/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1366.5225 - mean_absolute_error: 19.7697 - val_loss: 4377.8809 - val_mean_absolute_error: 21.3286
# Epoch 112/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1369.2804 - mean_absolute_error: 19.7971 - val_loss: 4394.5200 - val_mean_absolute_error: 21.8659
# Epoch 113/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1365.3546 - mean_absolute_error: 19.8511 - val_loss: 4407.1011 - val_mean_absolute_error: 21.5210
# Epoch 114/400
# 34/34 [==============================] - 2s 48ms/step - loss: 1366.2324 - mean_absolute_error: 19.8434 - val_loss: 4402.2427 - val_mean_absolute_error: 21.4423
# Epoch 115/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1373.1399 - mean_absolute_error: 19.8269 - val_loss: 4408.1504 - val_mean_absolute_error: 21.8956
# Epoch 116/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1363.5796 - mean_absolute_error: 19.8590 - val_loss: 4396.6362 - val_mean_absolute_error: 21.3740
# Epoch 117/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1347.9498 - mean_absolute_error: 19.6870 - val_loss: 4424.0015 - val_mean_absolute_error: 21.5643
# Epoch 118/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1348.1208 - mean_absolute_error: 19.6670 - val_loss: 4367.4473 - val_mean_absolute_error: 21.6017
# Epoch 119/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1371.9231 - mean_absolute_error: 19.9191 - val_loss: 4316.5181 - val_mean_absolute_error: 21.5467
# Epoch 120/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1410.3328 - mean_absolute_error: 20.1251 - val_loss: 4356.7100 - val_mean_absolute_error: 21.2198
# Epoch 121/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1412.7985 - mean_absolute_error: 20.1011 - val_loss: 4448.0635 - val_mean_absolute_error: 21.6940
# Epoch 122/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1397.9200 - mean_absolute_error: 20.2324 - val_loss: 4372.4150 - val_mean_absolute_error: 22.1148
# Epoch 123/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1374.5847 - mean_absolute_error: 19.9770 - val_loss: 4399.8892 - val_mean_absolute_error: 21.2844
# Epoch 124/400
# 34/34 [==============================] - 1s 34ms/step - loss: 1381.3064 - mean_absolute_error: 19.8179 - val_loss: 4377.1816 - val_mean_absolute_error: 21.1744
# Epoch 125/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1362.0150 - mean_absolute_error: 19.8031 - val_loss: 4376.9141 - val_mean_absolute_error: 21.3990
# Epoch 126/400
# 34/34 [==============================] - 1s 41ms/step - loss: 1386.3507 - mean_absolute_error: 19.8136 - val_loss: 4450.8062 - val_mean_absolute_error: 20.9772
# Epoch 127/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1391.0916 - mean_absolute_error: 20.1226 - val_loss: 4362.5767 - val_mean_absolute_error: 21.3227
# Epoch 128/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1379.0640 - mean_absolute_error: 19.9980 - val_loss: 4394.0513 - val_mean_absolute_error: 21.5450
# Epoch 129/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1359.7894 - mean_absolute_error: 19.9190 - val_loss: 4409.1045 - val_mean_absolute_error: 21.3261
# Epoch 130/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1371.4310 - mean_absolute_error: 19.8293 - val_loss: 4416.8247 - val_mean_absolute_error: 21.2070
# Epoch 131/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1363.3296 - mean_absolute_error: 19.8197 - val_loss: 4353.6631 - val_mean_absolute_error: 22.1507
# Epoch 132/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1371.9901 - mean_absolute_error: 20.1073 - val_loss: 4375.0635 - val_mean_absolute_error: 21.9117
# Epoch 133/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1356.9229 - mean_absolute_error: 19.8404 - val_loss: 4368.2764 - val_mean_absolute_error: 21.5195
# Epoch 134/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1352.8931 - mean_absolute_error: 19.8695 - val_loss: 4367.2578 - val_mean_absolute_error: 21.1694
# Epoch 135/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1338.3722 - mean_absolute_error: 19.6700 - val_loss: 4366.5420 - val_mean_absolute_error: 21.2562
# Epoch 136/400
# 34/34 [==============================] - 1s 35ms/step - loss: 1342.9998 - mean_absolute_error: 19.7136 - val_loss: 4358.6431 - val_mean_absolute_error: 21.7411
# Epoch 137/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1346.3064 - mean_absolute_error: 19.8365 - val_loss: 4376.6440 - val_mean_absolute_error: 21.5864
# Epoch 138/400
# 34/34 [==============================] - 1s 41ms/step - loss: 1353.8359 - mean_absolute_error: 19.8715 - val_loss: 4389.5869 - val_mean_absolute_error: 21.7279
# Epoch 139/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1363.5790 - mean_absolute_error: 19.8865 - val_loss: 4360.5288 - val_mean_absolute_error: 21.3494
# Epoch 140/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1351.1979 - mean_absolute_error: 19.8423 - val_loss: 4455.1919 - val_mean_absolute_error: 21.2023
# Epoch 141/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1335.4042 - mean_absolute_error: 19.6907 - val_loss: 4413.0850 - val_mean_absolute_error: 21.0906
# Epoch 142/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1332.3207 - mean_absolute_error: 19.6195 - val_loss: 4380.2061 - val_mean_absolute_error: 21.3105
# Epoch 143/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1329.3979 - mean_absolute_error: 19.5627 - val_loss: 4391.3252 - val_mean_absolute_error: 22.1339
# Epoch 144/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1338.3909 - mean_absolute_error: 19.7574 - val_loss: 4379.8481 - val_mean_absolute_error: 21.2343
# Epoch 145/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1329.4657 - mean_absolute_error: 19.5709 - val_loss: 4408.9658 - val_mean_absolute_error: 21.7130
# Epoch 146/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1326.8522 - mean_absolute_error: 19.5663 - val_loss: 4373.6714 - val_mean_absolute_error: 21.2527
# Epoch 147/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1326.1714 - mean_absolute_error: 19.6485 - val_loss: 4409.9111 - val_mean_absolute_error: 21.7661
# Epoch 148/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1322.5756 - mean_absolute_error: 19.6167 - val_loss: 4375.1411 - val_mean_absolute_error: 22.0193
# Epoch 149/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1335.6718 - mean_absolute_error: 19.7198 - val_loss: 4387.3823 - val_mean_absolute_error: 21.6607
# Epoch 150/400
# 34/34 [==============================] - 1s 40ms/step - loss: 1335.0636 - mean_absolute_error: 19.7519 - val_loss: 4365.9858 - val_mean_absolute_error: 21.7529
# Epoch 151/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1330.9471 - mean_absolute_error: 19.6565 - val_loss: 4382.4619 - val_mean_absolute_error: 21.1528
# Epoch 152/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1316.9270 - mean_absolute_error: 19.6229 - val_loss: 4353.2607 - val_mean_absolute_error: 21.2966
# Epoch 153/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1310.8423 - mean_absolute_error: 19.4814 - val_loss: 4385.0640 - val_mean_absolute_error: 21.4889
# Epoch 154/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1307.9624 - mean_absolute_error: 19.5146 - val_loss: 4386.4463 - val_mean_absolute_error: 21.4927
# Epoch 155/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1323.6504 - mean_absolute_error: 19.6478 - val_loss: 4415.3228 - val_mean_absolute_error: 21.2362
# Epoch 156/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1341.4700 - mean_absolute_error: 19.8538 - val_loss: 4365.1855 - val_mean_absolute_error: 21.0510
# Epoch 157/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1327.5703 - mean_absolute_error: 19.7413 - val_loss: 4370.3750 - val_mean_absolute_error: 21.6969
# Epoch 158/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1323.8024 - mean_absolute_error: 19.7449 - val_loss: 4337.4600 - val_mean_absolute_error: 21.5614
# Epoch 159/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1329.9607 - mean_absolute_error: 19.7654 - val_loss: 4396.0962 - val_mean_absolute_error: 21.2549
# Epoch 160/400
# 34/34 [==============================] - 2s 48ms/step - loss: 1321.1632 - mean_absolute_error: 19.8083 - val_loss: 4424.4429 - val_mean_absolute_error: 21.5566
# Epoch 161/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1309.3260 - mean_absolute_error: 19.6922 - val_loss: 4377.4302 - val_mean_absolute_error: 21.4946
# Epoch 162/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1303.0559 - mean_absolute_error: 19.6314 - val_loss: 4358.0493 - val_mean_absolute_error: 21.5279
# Epoch 163/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1292.7810 - mean_absolute_error: 19.5001 - val_loss: 4396.7476 - val_mean_absolute_error: 21.5252
# Epoch 164/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1295.7821 - mean_absolute_error: 19.5295 - val_loss: 4370.4097 - val_mean_absolute_error: 21.0624
# Epoch 165/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1291.7155 - mean_absolute_error: 19.5124 - val_loss: 4374.5000 - val_mean_absolute_error: 21.0322
# Epoch 166/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1292.2664 - mean_absolute_error: 19.5420 - val_loss: 4366.5342 - val_mean_absolute_error: 21.4610
# Epoch 167/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1290.6887 - mean_absolute_error: 19.4720 - val_loss: 4380.0161 - val_mean_absolute_error: 21.0146
# Epoch 168/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1288.9116 - mean_absolute_error: 19.4737 - val_loss: 4351.9536 - val_mean_absolute_error: 21.2477
# Epoch 169/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1281.0294 - mean_absolute_error: 19.3961 - val_loss: 4377.9531 - val_mean_absolute_error: 21.8426
# Epoch 170/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1285.9388 - mean_absolute_error: 19.4328 - val_loss: 4379.8589 - val_mean_absolute_error: 20.9776
# Epoch 171/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1277.4221 - mean_absolute_error: 19.3895 - val_loss: 4381.5786 - val_mean_absolute_error: 21.2545
# Epoch 172/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1277.8831 - mean_absolute_error: 19.4373 - val_loss: 4400.3809 - val_mean_absolute_error: 21.8400
# Epoch 173/400
# 34/34 [==============================] - 2s 45ms/step - loss: 1290.0564 - mean_absolute_error: 19.5658 - val_loss: 4412.0498 - val_mean_absolute_error: 21.5190
# Epoch 174/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1291.5785 - mean_absolute_error: 19.5846 - val_loss: 4394.5142 - val_mean_absolute_error: 20.9408
# Epoch 175/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1280.4349 - mean_absolute_error: 19.4320 - val_loss: 4380.8105 - val_mean_absolute_error: 21.0129
# Epoch 176/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1283.5925 - mean_absolute_error: 19.4262 - val_loss: 4354.9438 - val_mean_absolute_error: 21.4361
# Epoch 177/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1300.9822 - mean_absolute_error: 19.5676 - val_loss: 4408.7061 - val_mean_absolute_error: 21.3444
# Epoch 178/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1293.0547 - mean_absolute_error: 19.5252 - val_loss: 4363.1084 - val_mean_absolute_error: 21.3368
# Epoch 179/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1291.4473 - mean_absolute_error: 19.5914 - val_loss: 4413.4897 - val_mean_absolute_error: 20.8965
# Epoch 180/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1272.7501 - mean_absolute_error: 19.4143 - val_loss: 4391.0615 - val_mean_absolute_error: 21.4397
# Epoch 181/400
# 34/34 [==============================] - 1s 27ms/step - loss: 1288.8613 - mean_absolute_error: 19.5034 - val_loss: 4372.7026 - val_mean_absolute_error: 21.0943
# Epoch 182/400
# 34/34 [==============================] - 1s 42ms/step - loss: 1277.7385 - mean_absolute_error: 19.4602 - val_loss: 4307.6875 - val_mean_absolute_error: 20.9681
# Epoch 183/400
# 34/34 [==============================] - 2s 65ms/step - loss: 1256.9846 - mean_absolute_error: 19.2749 - val_loss: 4332.1650 - val_mean_absolute_error: 21.0313
# Epoch 184/400
# 34/34 [==============================] - 2s 56ms/step - loss: 1258.3140 - mean_absolute_error: 19.2556 - val_loss: 4335.7974 - val_mean_absolute_error: 20.8562
# Epoch 185/400
# 34/34 [==============================] - 1s 39ms/step - loss: 1276.4639 - mean_absolute_error: 19.5106 - val_loss: 4386.4941 - val_mean_absolute_error: 21.7296
# Epoch 186/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1316.5807 - mean_absolute_error: 19.7912 - val_loss: 4330.6235 - val_mean_absolute_error: 20.8990
# Epoch 187/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1276.8516 - mean_absolute_error: 19.4926 - val_loss: 4380.8232 - val_mean_absolute_error: 20.9857
# Epoch 188/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1264.9188 - mean_absolute_error: 19.2995 - val_loss: 4306.5698 - val_mean_absolute_error: 21.2579
# Epoch 189/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1259.6450 - mean_absolute_error: 19.2166 - val_loss: 4460.7612 - val_mean_absolute_error: 20.9295
# Epoch 190/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1251.4158 - mean_absolute_error: 19.2282 - val_loss: 4373.1001 - val_mean_absolute_error: 21.2718
# Epoch 191/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1286.1091 - mean_absolute_error: 19.5831 - val_loss: 4389.1348 - val_mean_absolute_error: 20.9351
# Epoch 192/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1249.2125 - mean_absolute_error: 19.3119 - val_loss: 4356.8594 - val_mean_absolute_error: 20.9946
# Epoch 193/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1257.0934 - mean_absolute_error: 19.2718 - val_loss: 4293.1689 - val_mean_absolute_error: 20.9263
# Epoch 194/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1234.1445 - mean_absolute_error: 19.1426 - val_loss: 4351.6689 - val_mean_absolute_error: 20.9183
# Epoch 195/400
# 34/34 [==============================] - 1s 42ms/step - loss: 1257.3214 - mean_absolute_error: 19.2430 - val_loss: 4385.2876 - val_mean_absolute_error: 21.2853
# Epoch 196/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1271.4608 - mean_absolute_error: 19.4518 - val_loss: 4288.8540 - val_mean_absolute_error: 21.3566
# Epoch 197/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1262.7836 - mean_absolute_error: 19.3038 - val_loss: 4386.6133 - val_mean_absolute_error: 21.0666
# Epoch 198/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1303.5657 - mean_absolute_error: 19.7074 - val_loss: 4359.0225 - val_mean_absolute_error: 21.6737
# Epoch 199/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1328.3236 - mean_absolute_error: 19.8860 - val_loss: 4353.4199 - val_mean_absolute_error: 21.9800
# Epoch 200/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1285.6373 - mean_absolute_error: 19.4869 - val_loss: 4323.4292 - val_mean_absolute_error: 21.4508
# Epoch 201/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1309.6641 - mean_absolute_error: 19.6291 - val_loss: 4455.1294 - val_mean_absolute_error: 20.9178
# Epoch 202/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1325.5535 - mean_absolute_error: 19.9377 - val_loss: 4418.7778 - val_mean_absolute_error: 20.9361
# Epoch 203/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1329.3912 - mean_absolute_error: 19.5909 - val_loss: 4352.2715 - val_mean_absolute_error: 21.0274
# Epoch 204/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1292.2028 - mean_absolute_error: 19.4830 - val_loss: 4304.9556 - val_mean_absolute_error: 21.2106
# Epoch 205/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1279.5996 - mean_absolute_error: 19.4434 - val_loss: 4346.9331 - val_mean_absolute_error: 21.2511
# Epoch 206/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1260.3042 - mean_absolute_error: 19.4439 - val_loss: 4277.3677 - val_mean_absolute_error: 21.2355
# Epoch 207/400
# 34/34 [==============================] - 2s 50ms/step - loss: 1288.8278 - mean_absolute_error: 19.4639 - val_loss: 4286.8950 - val_mean_absolute_error: 21.3383
# Epoch 208/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1370.2720 - mean_absolute_error: 20.1891 - val_loss: 4335.8438 - val_mean_absolute_error: 21.3601
# Epoch 209/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1326.9506 - mean_absolute_error: 20.2328 - val_loss: 4330.8560 - val_mean_absolute_error: 21.8132
# Epoch 210/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1320.2422 - mean_absolute_error: 19.9582 - val_loss: 4366.4268 - val_mean_absolute_error: 21.3302
# Epoch 211/400
# 34/34 [==============================] - 1s 28ms/step - loss: 1316.6372 - mean_absolute_error: 19.8823 - val_loss: 4377.2275 - val_mean_absolute_error: 21.6758
# Epoch 212/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1284.1648 - mean_absolute_error: 19.6190 - val_loss: 4336.9751 - val_mean_absolute_error: 22.1646
# Epoch 213/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1286.1376 - mean_absolute_error: 19.6445 - val_loss: 4260.7324 - val_mean_absolute_error: 21.6564
# Epoch 214/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1282.3881 - mean_absolute_error: 19.5614 - val_loss: 4242.4487 - val_mean_absolute_error: 21.3592
# Epoch 215/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1264.9690 - mean_absolute_error: 19.4557 - val_loss: 4277.3887 - val_mean_absolute_error: 21.3472
# Epoch 216/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1270.3525 - mean_absolute_error: 19.4481 - val_loss: 4260.9048 - val_mean_absolute_error: 21.4390
# Epoch 217/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1295.6669 - mean_absolute_error: 19.6408 - val_loss: 4285.1187 - val_mean_absolute_error: 22.2107
# Epoch 218/400
# 34/34 [==============================] - 1s 39ms/step - loss: 1302.4932 - mean_absolute_error: 19.8345 - val_loss: 4302.2207 - val_mean_absolute_error: 21.2243
# Epoch 219/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1291.7551 - mean_absolute_error: 19.7321 - val_loss: 4218.4102 - val_mean_absolute_error: 21.9824
# Epoch 220/400
# 34/34 [==============================] - 1s 38ms/step - loss: 1316.0164 - mean_absolute_error: 19.9836 - val_loss: 4394.1621 - val_mean_absolute_error: 20.9336
# Epoch 221/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1271.7408 - mean_absolute_error: 19.7068 - val_loss: 4273.0371 - val_mean_absolute_error: 21.2727
# Epoch 222/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1257.9186 - mean_absolute_error: 19.5851 - val_loss: 4280.6929 - val_mean_absolute_error: 21.1799
# Epoch 223/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1277.1514 - mean_absolute_error: 19.6914 - val_loss: 4243.0083 - val_mean_absolute_error: 21.4757
# Epoch 224/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1302.0183 - mean_absolute_error: 19.8490 - val_loss: 4233.5669 - val_mean_absolute_error: 21.9067
# Epoch 225/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1383.9242 - mean_absolute_error: 20.1282 - val_loss: 4386.5723 - val_mean_absolute_error: 21.4655
# Epoch 226/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1290.5057 - mean_absolute_error: 19.6686 - val_loss: 4197.7983 - val_mean_absolute_error: 21.2435
# Epoch 227/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1274.3365 - mean_absolute_error: 19.6250 - val_loss: 4264.7012 - val_mean_absolute_error: 21.4222
# Epoch 228/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1280.9803 - mean_absolute_error: 19.7299 - val_loss: 4314.5425 - val_mean_absolute_error: 21.3104
# Epoch 229/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1252.2294 - mean_absolute_error: 19.4364 - val_loss: 4325.2905 - val_mean_absolute_error: 21.8346
# Epoch 230/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1275.6326 - mean_absolute_error: 19.6292 - val_loss: 4324.6162 - val_mean_absolute_error: 21.5996
# Epoch 231/400
# 34/34 [==============================] - 1s 41ms/step - loss: 1307.1704 - mean_absolute_error: 19.6888 - val_loss: 4466.7017 - val_mean_absolute_error: 21.5661
# Epoch 232/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1319.6696 - mean_absolute_error: 20.1300 - val_loss: 4346.3853 - val_mean_absolute_error: 21.5833
# Epoch 233/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1290.7562 - mean_absolute_error: 19.7975 - val_loss: 4313.2686 - val_mean_absolute_error: 22.1170
# Epoch 234/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1347.2140 - mean_absolute_error: 19.9748 - val_loss: 4366.7153 - val_mean_absolute_error: 21.2378
# Epoch 235/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1308.5388 - mean_absolute_error: 20.0287 - val_loss: 4419.1543 - val_mean_absolute_error: 21.2321
# Epoch 236/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1252.9517 - mean_absolute_error: 19.4229 - val_loss: 4305.3662 - val_mean_absolute_error: 21.2533
# Epoch 237/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1246.1102 - mean_absolute_error: 19.4436 - val_loss: 4252.1470 - val_mean_absolute_error: 21.0663
# Epoch 238/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1260.0138 - mean_absolute_error: 19.4835 - val_loss: 4272.9409 - val_mean_absolute_error: 21.3076
# Epoch 239/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1306.2001 - mean_absolute_error: 19.7397 - val_loss: 4416.5781 - val_mean_absolute_error: 22.2677
# Epoch 240/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1284.3348 - mean_absolute_error: 19.7008 - val_loss: 4380.6167 - val_mean_absolute_error: 21.1263
# Epoch 241/400
# 34/34 [==============================] - 2s 49ms/step - loss: 1256.9797 - mean_absolute_error: 19.5582 - val_loss: 4391.3618 - val_mean_absolute_error: 20.9201
# Epoch 242/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1245.8348 - mean_absolute_error: 19.4764 - val_loss: 4405.2568 - val_mean_absolute_error: 21.6711
# Epoch 243/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1237.8156 - mean_absolute_error: 19.3404 - val_loss: 4276.7437 - val_mean_absolute_error: 21.8702
# Epoch 244/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1278.2054 - mean_absolute_error: 19.9241 - val_loss: 4384.6919 - val_mean_absolute_error: 21.1516
# Epoch 245/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1234.6780 - mean_absolute_error: 19.3166 - val_loss: 4295.6274 - val_mean_absolute_error: 21.4301
# Epoch 246/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1245.3407 - mean_absolute_error: 19.3126 - val_loss: 4311.0557 - val_mean_absolute_error: 21.6505
# Epoch 247/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1217.4697 - mean_absolute_error: 19.1868 - val_loss: 4306.3291 - val_mean_absolute_error: 22.2875
# Epoch 248/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1234.7753 - mean_absolute_error: 19.3288 - val_loss: 4302.0459 - val_mean_absolute_error: 21.0204
# Epoch 249/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1235.5470 - mean_absolute_error: 19.3129 - val_loss: 4327.2773 - val_mean_absolute_error: 21.0797
# Epoch 250/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1212.5834 - mean_absolute_error: 19.1666 - val_loss: 4279.3467 - val_mean_absolute_error: 21.6652
# Epoch 251/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1244.5425 - mean_absolute_error: 19.4290 - val_loss: 4387.7417 - val_mean_absolute_error: 20.9341
# Epoch 252/400
# 34/34 [==============================] - 1s 41ms/step - loss: 1217.9968 - mean_absolute_error: 19.3292 - val_loss: 4334.4238 - val_mean_absolute_error: 21.0814
# Epoch 253/400
# 34/34 [==============================] - 2s 53ms/step - loss: 1250.8787 - mean_absolute_error: 19.5108 - val_loss: 4395.2300 - val_mean_absolute_error: 21.2287
# Epoch 254/400
# 34/34 [==============================] - 1s 36ms/step - loss: 1273.7152 - mean_absolute_error: 19.5041 - val_loss: 4355.7651 - val_mean_absolute_error: 22.3898
# Epoch 255/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1315.2209 - mean_absolute_error: 20.2173 - val_loss: 4423.4810 - val_mean_absolute_error: 23.4776
# Epoch 256/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1291.3145 - mean_absolute_error: 20.1356 - val_loss: 4491.0435 - val_mean_absolute_error: 21.0618
# Epoch 257/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1241.6163 - mean_absolute_error: 19.4121 - val_loss: 4443.8403 - val_mean_absolute_error: 21.4950
# Epoch 258/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1239.3499 - mean_absolute_error: 19.4007 - val_loss: 4309.0674 - val_mean_absolute_error: 22.4165
# Epoch 259/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1252.6340 - mean_absolute_error: 19.3944 - val_loss: 4426.8540 - val_mean_absolute_error: 21.9480
# Epoch 260/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1236.4741 - mean_absolute_error: 19.3890 - val_loss: 4382.5688 - val_mean_absolute_error: 21.1504
# Epoch 261/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1263.7244 - mean_absolute_error: 19.6218 - val_loss: 4277.1304 - val_mean_absolute_error: 21.7071
# Epoch 262/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1227.8510 - mean_absolute_error: 19.3159 - val_loss: 4287.3989 - val_mean_absolute_error: 20.7829
# Epoch 263/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1206.1255 - mean_absolute_error: 19.0804 - val_loss: 4321.8955 - val_mean_absolute_error: 22.1161
# Epoch 264/400
# 34/34 [==============================] - 2s 49ms/step - loss: 1230.4700 - mean_absolute_error: 19.4806 - val_loss: 4226.2178 - val_mean_absolute_error: 21.1976
# Epoch 265/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1237.9946 - mean_absolute_error: 19.2840 - val_loss: 4405.2007 - val_mean_absolute_error: 21.0955
# Epoch 266/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1215.6591 - mean_absolute_error: 19.3700 - val_loss: 4337.5679 - val_mean_absolute_error: 21.2014
# Epoch 267/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1197.1520 - mean_absolute_error: 18.9436 - val_loss: 4396.9121 - val_mean_absolute_error: 21.0911
# Epoch 268/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1193.4642 - mean_absolute_error: 19.1414 - val_loss: 4361.8228 - val_mean_absolute_error: 21.1456
# Epoch 269/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1198.4045 - mean_absolute_error: 19.0040 - val_loss: 4277.8662 - val_mean_absolute_error: 21.2578
# Epoch 270/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1193.2808 - mean_absolute_error: 19.1710 - val_loss: 4322.1245 - val_mean_absolute_error: 21.2357
# Epoch 271/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1233.7133 - mean_absolute_error: 19.5022 - val_loss: 4349.6772 - val_mean_absolute_error: 23.0792
# Epoch 272/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1293.3257 - mean_absolute_error: 20.2302 - val_loss: 4361.8291 - val_mean_absolute_error: 21.9585
# Epoch 273/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1241.6865 - mean_absolute_error: 19.5499 - val_loss: 4309.6909 - val_mean_absolute_error: 21.5451
# Epoch 274/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1230.9700 - mean_absolute_error: 19.4103 - val_loss: 4352.0801 - val_mean_absolute_error: 20.7652
# Epoch 275/400
# 34/34 [==============================] - 2s 47ms/step - loss: 1186.1146 - mean_absolute_error: 18.9878 - val_loss: 4384.1616 - val_mean_absolute_error: 21.0749
# Epoch 276/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1217.1965 - mean_absolute_error: 19.0757 - val_loss: 4298.9585 - val_mean_absolute_error: 23.6652
# Epoch 277/400
# ...
# 34/34 [==============================] - 2s 51ms/step - loss: 1387.1045 - mean_absolute_error: 20.5845 - val_loss: 4326.2578 - val_mean_absolute_error: 21.7530
# Epoch 310/400
# 34/34 [==============================] - 2s 49ms/step - loss: 1387.1201 - mean_absolute_error: 20.3648 - val_loss: 4371.1025 - val_mean_absolute_error: 21.6771
# Epoch 311/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1362.8317 - mean_absolute_error: 20.3208 - val_loss: 4363.3149 - val_mean_absolute_error: 22.2060
# Epoch 312/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1358.1508 - mean_absolute_error: 20.2275 - val_loss: 4421.7466 - val_mean_absolute_error: 22.7489
# Epoch 313/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1391.5890 - mean_absolute_error: 20.5121 - val_loss: 4304.4595 - val_mean_absolute_error: 21.1456
# Epoch 314/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1373.7717 - mean_absolute_error: 20.3760 - val_loss: 4262.9805 - val_mean_absolute_error: 21.5513
# Epoch 315/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1371.3762 - mean_absolute_error: 20.5397 - val_loss: 4347.1387 - val_mean_absolute_error: 21.3034
# Epoch 316/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1361.1349 - mean_absolute_error: 20.3144 - val_loss: 4321.4932 - val_mean_absolute_error: 21.3386
# Epoch 317/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1374.1167 - mean_absolute_error: 20.3575 - val_loss: 4336.8442 - val_mean_absolute_error: 21.4746
# Epoch 318/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1349.3301 - mean_absolute_error: 20.1109 - val_loss: 4316.7729 - val_mean_absolute_error: 21.2883
# Epoch 319/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1334.4998 - mean_absolute_error: 20.0397 - val_loss: 4314.9780 - val_mean_absolute_error: 21.2964
# Epoch 320/400
# 34/34 [==============================] - 2s 50ms/step - loss: 1353.7749 - mean_absolute_error: 20.2565 - val_loss: 4355.4995 - val_mean_absolute_error: 21.2135
# Epoch 321/400
# 34/34 [==============================] - 2s 53ms/step - loss: 1340.1221 - mean_absolute_error: 20.2876 - val_loss: 4337.1675 - val_mean_absolute_error: 21.2882
# Epoch 322/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1316.5951 - mean_absolute_error: 19.9825 - val_loss: 4248.4482 - val_mean_absolute_error: 21.2989
# Epoch 323/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1321.6178 - mean_absolute_error: 20.0713 - val_loss: 4391.0757 - val_mean_absolute_error: 21.2947
# Epoch 324/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1326.1305 - mean_absolute_error: 20.0408 - val_loss: 4296.3540 - val_mean_absolute_error: 21.2573
# Epoch 325/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1337.6537 - mean_absolute_error: 20.1472 - val_loss: 4428.5454 - val_mean_absolute_error: 21.3245
# Epoch 326/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1394.7119 - mean_absolute_error: 20.3676 - val_loss: 4403.3213 - val_mean_absolute_error: 21.3061
# Epoch 327/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1354.8131 - mean_absolute_error: 20.2563 - val_loss: 4296.9473 - val_mean_absolute_error: 21.3006
# Epoch 328/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1342.6842 - mean_absolute_error: 20.0967 - val_loss: 4272.9248 - val_mean_absolute_error: 21.4379
# Epoch 329/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1332.8973 - mean_absolute_error: 20.0274 - val_loss: 4261.2026 - val_mean_absolute_error: 21.3134
# Epoch 330/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1342.2095 - mean_absolute_error: 20.1020 - val_loss: 4295.2905 - val_mean_absolute_error: 21.5155
# Epoch 331/400
# 34/34 [==============================] - 1s 42ms/step - loss: 1330.2548 - mean_absolute_error: 19.9089 - val_loss: 4252.2822 - val_mean_absolute_error: 21.4606
# Epoch 332/400
# 34/34 [==============================] - 2s 53ms/step - loss: 1319.2817 - mean_absolute_error: 19.9806 - val_loss: 4229.8823 - val_mean_absolute_error: 20.9219
# Epoch 333/400
# 34/34 [==============================] - 1s 36ms/step - loss: 1323.3535 - mean_absolute_error: 19.8955 - val_loss: 4285.8481 - val_mean_absolute_error: 21.1228
# Epoch 334/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1321.6091 - mean_absolute_error: 19.8513 - val_loss: 4418.8306 - val_mean_absolute_error: 21.3007
# Epoch 335/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1302.2041 - mean_absolute_error: 19.8377 - val_loss: 4349.8828 - val_mean_absolute_error: 21.1994
# Epoch 336/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1295.2859 - mean_absolute_error: 19.7675 - val_loss: 4269.7891 - val_mean_absolute_error: 21.5025
# Epoch 337/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1305.2208 - mean_absolute_error: 19.8537 - val_loss: 4386.6299 - val_mean_absolute_error: 21.8221
# Epoch 338/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1319.4749 - mean_absolute_error: 20.0141 - val_loss: 4323.4102 - val_mean_absolute_error: 21.2841
# Epoch 339/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1309.4648 - mean_absolute_error: 19.7996 - val_loss: 4338.9058 - val_mean_absolute_error: 21.5054
# Epoch 340/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1307.4686 - mean_absolute_error: 19.9465 - val_loss: 4283.5801 - val_mean_absolute_error: 21.6256
# Epoch 341/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1332.2400 - mean_absolute_error: 19.9804 - val_loss: 4352.1270 - val_mean_absolute_error: 21.4774
# Epoch 342/400
# 34/34 [==============================] - 1s 39ms/step - loss: 1323.1813 - mean_absolute_error: 20.0255 - val_loss: 4254.5737 - val_mean_absolute_error: 21.5049
# Epoch 343/400
# 34/34 [==============================] - 2s 53ms/step - loss: 1310.2793 - mean_absolute_error: 19.8506 - val_loss: 4317.5142 - val_mean_absolute_error: 21.3787
# Epoch 344/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1290.5691 - mean_absolute_error: 19.7278 - val_loss: 4311.3232 - val_mean_absolute_error: 21.1636
# Epoch 345/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1301.2612 - mean_absolute_error: 19.8273 - val_loss: 4350.9287 - val_mean_absolute_error: 21.7351
# Epoch 346/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1314.9031 - mean_absolute_error: 19.9051 - val_loss: 4275.5425 - val_mean_absolute_error: 21.1362
# Epoch 347/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1295.0830 - mean_absolute_error: 19.8550 - val_loss: 4361.9888 - val_mean_absolute_error: 21.2246
# Epoch 348/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1294.6099 - mean_absolute_error: 19.7517 - val_loss: 4173.2144 - val_mean_absolute_error: 22.1345
# Epoch 349/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1295.5840 - mean_absolute_error: 19.8168 - val_loss: 4347.5317 - val_mean_absolute_error: 21.8866
# Epoch 350/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1279.6089 - mean_absolute_error: 19.7905 - val_loss: 4222.0801 - val_mean_absolute_error: 21.4962
# Epoch 351/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1295.4467 - mean_absolute_error: 19.6927 - val_loss: 4294.2720 - val_mean_absolute_error: 21.4948
# Epoch 352/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1284.5320 - mean_absolute_error: 19.7337 - val_loss: 4323.8882 - val_mean_absolute_error: 21.0245
# Epoch 353/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1275.5715 - mean_absolute_error: 19.6679 - val_loss: 4245.1284 - val_mean_absolute_error: 21.4620
# Epoch 354/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1284.0046 - mean_absolute_error: 19.7492 - val_loss: 4305.4199 - val_mean_absolute_error: 21.0246
# Epoch 355/400
# 34/34 [==============================] - 2s 50ms/step - loss: 1265.0160 - mean_absolute_error: 19.4961 - val_loss: 4300.8525 - val_mean_absolute_error: 21.7072
# Epoch 356/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1268.9500 - mean_absolute_error: 19.7149 - val_loss: 4363.6455 - val_mean_absolute_error: 21.2524
# Epoch 357/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1260.4712 - mean_absolute_error: 19.5127 - val_loss: 4319.1138 - val_mean_absolute_error: 21.3793
# Epoch 358/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1272.1566 - mean_absolute_error: 19.6286 - val_loss: 4318.1694 - val_mean_absolute_error: 21.9890
# Epoch 359/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1284.3071 - mean_absolute_error: 19.6588 - val_loss: 4259.9507 - val_mean_absolute_error: 22.1551
# Epoch 360/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1343.4329 - mean_absolute_error: 20.2410 - val_loss: 4422.9272 - val_mean_absolute_error: 21.1871
# Epoch 361/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1304.0557 - mean_absolute_error: 20.0362 - val_loss: 4326.3071 - val_mean_absolute_error: 21.1095
# Epoch 362/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1279.3035 - mean_absolute_error: 19.7009 - val_loss: 4301.1343 - val_mean_absolute_error: 21.9451
# Epoch 363/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1312.6007 - mean_absolute_error: 20.1487 - val_loss: 4302.9668 - val_mean_absolute_error: 21.5806
# Epoch 364/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1282.3390 - mean_absolute_error: 19.7965 - val_loss: 4279.5029 - val_mean_absolute_error: 21.5996
# Epoch 365/400
# 34/34 [==============================] - 2s 46ms/step - loss: 1281.6005 - mean_absolute_error: 19.8037 - val_loss: 4343.4624 - val_mean_absolute_error: 21.7909
# Epoch 366/400
# 34/34 [==============================] - 2s 52ms/step - loss: 1277.8602 - mean_absolute_error: 19.6756 - val_loss: 4310.0542 - val_mean_absolute_error: 21.8680
# Epoch 367/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1296.8168 - mean_absolute_error: 19.9328 - val_loss: 4303.3584 - val_mean_absolute_error: 21.8799
# Epoch 368/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1313.2317 - mean_absolute_error: 20.1336 - val_loss: 4387.0972 - val_mean_absolute_error: 21.5795
# Epoch 369/400
# 34/34 [==============================] - 1s 33ms/step - loss: 1265.5815 - mean_absolute_error: 19.7608 - val_loss: 4309.8560 - val_mean_absolute_error: 21.5647
# Epoch 370/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1259.6996 - mean_absolute_error: 19.7345 - val_loss: 4366.8667 - val_mean_absolute_error: 20.9620
# Epoch 371/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1258.8566 - mean_absolute_error: 19.5773 - val_loss: 4285.8452 - val_mean_absolute_error: 21.5960
# Epoch 372/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1231.8054 - mean_absolute_error: 19.4400 - val_loss: 4326.0591 - val_mean_absolute_error: 21.1325
# Epoch 373/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1225.3207 - mean_absolute_error: 19.3017 - val_loss: 4289.5854 - val_mean_absolute_error: 21.6534
# Epoch 374/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1248.8513 - mean_absolute_error: 19.5130 - val_loss: 4263.2515 - val_mean_absolute_error: 21.7867
# Epoch 375/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1356.1078 - mean_absolute_error: 19.9821 - val_loss: 4433.8149 - val_mean_absolute_error: 22.2403
# Epoch 376/400
# 34/34 [==============================] - 1s 37ms/step - loss: 1300.8011 - mean_absolute_error: 20.0041 - val_loss: 4422.4360 - val_mean_absolute_error: 21.4593
# Epoch 377/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1312.5574 - mean_absolute_error: 20.0494 - val_loss: 4388.3066 - val_mean_absolute_error: 21.8763
# Epoch 378/400
# 34/34 [==============================] - 2s 44ms/step - loss: 1278.1479 - mean_absolute_error: 19.9774 - val_loss: 4349.6973 - val_mean_absolute_error: 21.3725
# Epoch 379/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1298.5558 - mean_absolute_error: 19.6378 - val_loss: 4293.9111 - val_mean_absolute_error: 22.6062
# Epoch 380/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1342.2572 - mean_absolute_error: 19.9886 - val_loss: 4373.1338 - val_mean_absolute_error: 21.2831
# Epoch 381/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1283.5658 - mean_absolute_error: 19.6897 - val_loss: 4404.6348 - val_mean_absolute_error: 21.3033
# Epoch 382/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1295.0049 - mean_absolute_error: 19.7363 - val_loss: 4366.1152 - val_mean_absolute_error: 20.7661
# Epoch 383/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1290.5358 - mean_absolute_error: 19.6659 - val_loss: 4295.5688 - val_mean_absolute_error: 21.3592
# Epoch 384/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1275.3805 - mean_absolute_error: 19.5707 - val_loss: 4336.3184 - val_mean_absolute_error: 21.5315
# Epoch 385/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1257.6394 - mean_absolute_error: 19.6222 - val_loss: 4360.5347 - val_mean_absolute_error: 20.4877
# Epoch 386/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1257.8535 - mean_absolute_error: 19.6164 - val_loss: 4261.8066 - val_mean_absolute_error: 21.6408
# Epoch 387/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1258.0754 - mean_absolute_error: 19.5882 - val_loss: 4318.9937 - val_mean_absolute_error: 20.5910
# Epoch 388/400
# 34/34 [==============================] - 2s 51ms/step - loss: 1257.4937 - mean_absolute_error: 19.3618 - val_loss: 4528.4785 - val_mean_absolute_error: 21.0071
# Epoch 389/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1323.8142 - mean_absolute_error: 20.1178 - val_loss: 4363.0273 - val_mean_absolute_error: 22.2873
# Epoch 390/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1255.5060 - mean_absolute_error: 19.6351 - val_loss: 4352.0532 - val_mean_absolute_error: 21.2704
# Epoch 391/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1240.7025 - mean_absolute_error: 19.4199 - val_loss: 4387.4771 - val_mean_absolute_error: 21.3274
# Epoch 392/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1241.7515 - mean_absolute_error: 19.4048 - val_loss: 4359.7876 - val_mean_absolute_error: 21.5822
# Epoch 393/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1229.6458 - mean_absolute_error: 19.3745 - val_loss: 4349.3418 - val_mean_absolute_error: 21.5049
# Epoch 394/400
# 34/34 [==============================] - 1s 32ms/step - loss: 1218.7799 - mean_absolute_error: 19.3202 - val_loss: 4373.9141 - val_mean_absolute_error: 21.2215
# Epoch 395/400
# 34/34 [==============================] - 1s 30ms/step - loss: 1227.7168 - mean_absolute_error: 19.3727 - val_loss: 4368.8691 - val_mean_absolute_error: 22.6723
# Epoch 396/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1297.5092 - mean_absolute_error: 19.6320 - val_loss: 4406.5259 - val_mean_absolute_error: 21.1136
# Epoch 397/400
# 34/34 [==============================] - 1s 29ms/step - loss: 1259.1982 - mean_absolute_error: 19.6706 - val_loss: 4352.1675 - val_mean_absolute_error: 21.4757
# Epoch 398/400
# 34/34 [==============================] - 1s 31ms/step - loss: 1235.9207 - mean_absolute_error: 19.5662 - val_loss: 4338.8843 - val_mean_absolute_error: 20.8037
# Epoch 399/400
# 34/34 [==============================] - 1s 41ms/step - loss: 1218.1172 - mean_absolute_error: 19.3800 - val_loss: 4346.7100 - val_mean_absolute_error: 20.7703
# Epoch 400/400
# 34/34 [==============================] - 2s 54ms/step - loss: 1206.5209 - mean_absolute_error: 19.1305 - val_loss: 4381.5381 - val_mean_absolute_error: 21.2367

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss', linewidth=1,color='green')
    plt.plot(epochs, val_loss, 'r', label='Validation loss', linewidth=1,color='purple')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(history,
                   'Training and validation loss')
# Out:
# <ipython-input-106-6b1627954cc9>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'b', label='Training loss', linewidth=1,color='green')
# <ipython-input-106-6b1627954cc9>:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'r', label='Validation loss', linewidth=1,color='purple')

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 73/73 [==============================] - 1s 4ms/step

# %%
y_pred
# Out:
# array([[[ 65.57898 ],
#         [ 63.164906],
#         [ 67.609116],
#         ...,
#         [ 51.87889 ],
#         [ 53.82296 ],
#         [ 54.50404 ]],
#
#        [[ 32.28791 ],
#         [ 29.70803 ],
#         [ 26.068333],
#         ...,
#         [ 24.842068],
#         [ 30.681286],
#         [ 33.90056 ]],
#
#        [[ 75.14002 ],
#         [ 87.277176],
#         [ 99.99667 ],
#         ...,
#         [102.12016 ],
#         [ 97.79    ],
#         [ 98.02222 ]],
#
#        ...,
#
#        [[ 71.66168 ],
#         [ 76.34198 ],
#         [ 99.94827 ],
#         ...,
#         [ 95.14261 ],
#         [ 84.552605],
#         [ 98.94203 ]],
#
#        [[ 26.13095 ],
#         [ 24.764977],
#         [ 20.888142],
#         ...,
#         [ 21.1778  ],
#         [ 21.914341],
#         [ 20.250118]],
#
#        [[108.743286],
#         [ 99.94    ],
#         [103.60908 ],
#         ...,
#         [ 64.10435 ],
#         [ 67.99649 ],
#         [ 68.90268 ]]], dtype=float32)

# %%
y_test
# Out:
# array([[ 66.3 ],
#        [ 25.89],
#        [108.65],
#        ...,
#        [ 94.57],
#        [ 22.53],
#        [100.58]])

# %%
plt.figure(figsize=(6,3))


plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 24-hour ahead predictions")

hour= 24
n_day = 365
plot_day = hour*n_day

plt.plot(y_pred[:,-1], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test[:, -1], label='True', linewidth=1,color='purple')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 24-hour ahead predictions")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
errors = y_pred- y_test
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()

print('Mean Absolute Error: {:.2f}'.format(mae))
print('Root Mean Square Error: {:.2f}'.format(rmse))
print('R2 Score: ', r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-587847f0bcd5> in <cell line: 2>()
#       1 from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# ----> 2 errors = y_pred- y_test
#       3 mse = np.square(errors).mean()
#       4 rmse = np.sqrt(mse)
#       5 mae = np.abs(errors).mean()
#
# ValueError: operands could not be broadcast together with shapes (2308,11,1) (2308,1)

# %%
plt.figure(figsize=(6,3))


plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022 24-hour ahead predictions")

hour= 24
n_day = 365
plot_day = hour*n_day

plt.plot(y_pred[:,-1], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test[:, -1], label='True', linewidth=1,color='purple')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,3))


plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği")

hour= 24
n_day = 365
plot_day = hour*n_day

plt.plot(y_pred[:,-1], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test[:, -1], label='Gerçek', linewidth=1,color='purple')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022 24-hour ahead predictions for '30' days")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 30 Günlük")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 June 24 h Ahead Prediction, 5 Days")

hour= 24
n_day = 5
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 5 Günlük")

hour= 24
n_day = 5
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 1 Günlük")

hour= 24
n_day = 1
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-New Eng 2022-2023 June 24 h Ahead Prediction, 1 Day")

hour= 24
n_day = 1
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
errors = y_pred- y_test
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()

print('Mean Absolute Error: {:.2f}'.format(mae))
print('Root Mean Square Error: {:.2f}'.format(rmse))
print('R2 Score: ', r2_score(y_test, y_pred))
