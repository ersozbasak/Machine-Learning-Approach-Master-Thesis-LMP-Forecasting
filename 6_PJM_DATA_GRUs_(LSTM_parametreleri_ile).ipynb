# %% [markdown]
# <a href="https://colab.research.google.com/github/ersozbasak/Machine-Learning-Regression-Models/blob/master/6_PJM_DATA_GRUs_(LSTM_parametreleri_ile).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# EVALUATION OF PJM VALUES

# %% [markdown]
# 1. Introduction and Integration (Regularization the Data Set)
# 2. Machine Learning Integration
# 3. Deep Learning Integration

# %% [markdown]
# ### Regularization the Data Set

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import gc
import sys
#mpl.rcParams['figure.figsize'] = (17, 5)
#mpl.rcParams['axes.grid'] = False
#sns.set_style("whitegrid")
from pandas import DataFrame , concat
from sklearn.metrics import mean_absolute_error , mean_squared_error
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from numpy import mean , concatenate
from math import sqrt
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation,Dropout
from numpy import array , hstack
from tensorflow import keras
import tensorflow as tf
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/PJM_Values
# %ls
# Out:
# /content/drive/MyDrive/PJM_Values
# dataset.pkl                        rt_hrl_lmps_JUNE_AGU.csv
# KNN_PJM_dataset.csv                rt_hrl_lmps_MARCH_MAY.csv
# LSTM_PJM/                          rt_hrl_lmps_SEP_NOV.csv
# rt_hrl_lmps_22JUNE_23JUNE_ALL.csv  structured_data_classifier/
# rt_hrl_lmps_DEC_FEB.csv            structured_data_regressor/

# %%
df_22JUNE_23JUNE_ALL = pd.read_csv('/content/drive/MyDrive/PJM_Values/rt_hrl_lmps_22JUNE_23JUNE_ALL.csv',engine='python',encoding='utf-8')
df_JUNE_AGU = pd.read_csv('/content/drive/MyDrive/PJM_Values/rt_hrl_lmps_JUNE_AGU.csv',engine='python',encoding='utf-8')
df_SEP_NOV = pd.read_csv('/content/drive/MyDrive/PJM_Values/rt_hrl_lmps_SEP_NOV.csv',engine='python',encoding='utf-8')
df_DEC_FEB = pd.read_csv('/content/drive/MyDrive/PJM_Values/rt_hrl_lmps_DEC_FEB.csv',engine='python',encoding='utf-8')
df_MARCH_MAY = pd.read_csv('/content/drive/MyDrive/PJM_Values/rt_hrl_lmps_MARCH_MAY.csv',engine='python',encoding='utf-8')

# %%
"""lmp_DEC_FEB = df_DEC_FEB[df_DEC_FEB['VALUE'].isin(['LMP'])]
lmp_MARCH_MAY = df_MARCH_MAY[df_MARCH_MAY['VALUE'].isin(['LMP'])]
lmp_JUNE_AGU = df_JUNE_AGU[df_JUNE_AGU['VALUE'].isin(['LMP'])]
lmp_SEP_NOV = df_SEP_NOV[df_SEP_NOV['VALUE'].isin(['LMP'])]
loadzone_DEC_FEB = lmp_DEC_FEB[lmp_DEC_FEB['TYPE'].isin(['Loadzone'])]
loadzone_MARCH_MAY = lmp_MARCH_MAY[lmp_MARCH_MAY['TYPE'].isin(['Loadzone'])]
loadzone_JUNE_AGU = lmp_JUNE_AGU[lmp_JUNE_AGU['TYPE'].isin(['Loadzone'])]
loadzone_SEP_NOV = lmp_SEP_NOV[lmp_SEP_NOV['TYPE'].isin(['Loadzone'])]"""
# Out:
# "lmp_DEC_FEB = df_DEC_FEB[df_DEC_FEB['VALUE'].isin(['LMP'])]\nlmp_MARCH_MAY = df_MARCH_MAY[df_MARCH_MAY['VALUE'].isin(['LMP'])]\nlmp_JUNE_AGU = df_JUNE_AGU[df_JUNE_AGU['VALUE'].isin(['LMP'])]\nlmp_SEP_NOV = df_SEP_NOV[df_SEP_NOV['VALUE'].isin(['LMP'])]\nloadzone_DEC_FEB = lmp_DEC_FEB[lmp_DEC_FEB['TYPE'].isin(['Loadzone'])]\nloadzone_MARCH_MAY = lmp_MARCH_MAY[lmp_MARCH_MAY['TYPE'].isin(['Loadzone'])]\nloadzone_JUNE_AGU = lmp_JUNE_AGU[lmp_JUNE_AGU['TYPE'].isin(['Loadzone'])]\nloadzone_SEP_NOV = lmp_SEP_NOV[lmp_SEP_NOV['TYPE'].isin(['Loadzone'])]"

# %%
grouped_df_ALL = df_22JUNE_23JUNE_ALL.groupby('pnode_name')# Group HUB dataframe by the 'pnode_name' column
group_names_jm = grouped_df_ALL.groups.keys()# Get the names of each group = 12

# %%
len(group_names_jm)
# Out:
# 12

# %%
df_list_22_23 = [ df_22JUNE_23JUNE_ALL]

for i in df_list_22_23:
    i.drop('datetime_beginning_utc', inplace=True, axis=1)
    i.drop('datetime_beginning_ept', inplace=True, axis=1)
    i.drop('pnode_id', inplace=True, axis=1)
    i.drop('voltage', inplace=True, axis=1)
    i.drop('equipment', inplace=True, axis=1)
    i.drop('type', inplace=True, axis=1)
    i.drop('zone', inplace=True, axis=1)
    i.drop('congestion_price_rt', inplace=True, axis=1)
    i.drop('marginal_loss_price_rt', inplace=True, axis=1)
    i.drop('system_energy_price_rt', inplace=True, axis=1)
    i.drop('row_is_current', inplace=True, axis=1)
    i.drop('version_nbr', inplace=True, axis=1)

# %%
print(df_22JUNE_23JUNE_ALL.dtypes)
# Out:
# pnode_name       object
# total_lmp_rt    float64
# dtype: object

# %%
df_22JUNE_23JUNE_ALL.head()
# Out:
#         pnode_name  total_lmp_rt
# 0      EASTERN HUB     69.669366
# 1     WEST INT HUB     67.783333
# 2      WESTERN HUB     68.755145
# 3   NEW JERSEY HUB     69.168388
# 4  CHICAGO GEN HUB     65.559705

# %%
common_nodes = set(df_22JUNE_23JUNE_ALL['pnode_name'].unique())
df_22JUNE_23JUNE_ALL_filtered=df_22JUNE_23JUNE_ALL[df_22JUNE_23JUNE_ALL['pnode_name'].isin(common_nodes)]

# %%
df_22JUNE_23JUNE_ALL_filtered
# Out:
#              pnode_name  total_lmp_rt
# 0           EASTERN HUB     69.669366
# 1          WEST INT HUB     67.783333
# 2           WESTERN HUB     68.755145
# 3        NEW JERSEY HUB     69.168388
# 4       CHICAGO GEN HUB     65.559705
# ...                 ...           ...
# 105415      AEP GEN HUB     17.748531
# 105416   AEP-DAYTON HUB     18.123747
# 105417         OHIO HUB     18.155619
# 105418     DOMINION HUB     18.230117
# 105419     ATSI GEN HUB     17.634527
#
# [105420 rows x 2 columns]

# %%
count_nan=df_22JUNE_23JUNE_ALL_filtered.isnull().sum()
# printing the number of values present
# in the column
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: pnode_name      0
# total_lmp_rt    0
# dtype: int64

# %%
grouped_df = df_22JUNE_23JUNE_ALL_filtered.groupby('pnode_name')# Group the loadzone_2016 dataframe by the 'NODE' column
group_names = grouped_df.groups.keys()# Get the names of each group
len(group_names)
# Out:
# 12

# %%
# group the merged_df dataframe by the 'NODE' column
grouped_df = df_22JUNE_23JUNE_ALL_filtered.groupby('pnode_name')

# get the names of each group
group_names = grouped_df.groups.keys()

node_list = []

# iterate through the grouped dataframe, get each group by its name, and append it to the node_list
for key, item in grouped_df:
    node_df = grouped_df.get_group(key)
    node_list.append(node_df)

stacked_df = []

# iterate through the node_list, drop the 'NODE' column, stack the dataframe, and append it to the stacked_df
for i in node_list:
    i_drop = i.drop('pnode_name', axis=1)
    s_df = i_drop.stack().reset_index(drop=True)
    stacked_df.append(s_df)

node_dfs = {}
df_list = []

# iterate through the group_names, create a dataframe for each node, and append it to the df_list
for i, node in enumerate(group_names):
    node_dfs[node] = pd.DataFrame(stacked_df[i], columns=[node])
    df_list.append(node_dfs[node])

# concatenate the dataframes in the df_list along the columns to get the final dataframe
df_all_2223 = pd.concat(df_list, axis=1)

# %%
df_all_2223.head()
# Out:
#    AEP GEN HUB  AEP-DAYTON HUB  ATSI GEN HUB  CHICAGO GEN HUB  CHICAGO HUB  \
# 0    66.526689       68.095556     67.318277        65.559705    66.693074
# 1    73.990110       75.501068     74.708125        72.656474    73.844903
# 2    55.928728       56.996921     56.571705        54.765039    55.588311
# 3    52.131930       53.100233     52.694148        51.074570    51.790448
# 4    51.751316       52.390917     51.786250        49.386083    50.045211
#
#    DOMINION HUB  EASTERN HUB  N ILLINOIS HUB  NEW JERSEY HUB   OHIO HUB  \
# 0     69.495414    69.669366       66.248896       69.168388  68.268067
# 1     77.405280    77.793004       73.368035       77.122941  75.629564
# 2     58.358574    58.999558       55.258335       58.545221  57.086478
# 3     54.294922    54.701800       51.508351       54.240732  53.176826
# 4     53.740003    53.799772       49.809685       53.344182  52.374108
#
#    WEST INT HUB  WESTERN HUB
# 0     67.783333    68.755145
# 1     75.400555    76.753895
# 2     57.017916    58.048027
# 3     53.095880    53.991960
# 4     52.381388    53.275979

# %%
count_nan = df_all_2223.isnull().sum()
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: AEP GEN HUB        0
# AEP-DAYTON HUB     0
# ATSI GEN HUB       0
# CHICAGO GEN HUB    0
# CHICAGO HUB        0
# DOMINION HUB       0
# EASTERN HUB        0
# N ILLINOIS HUB     0
# NEW JERSEY HUB     0
# OHIO HUB           0
# WEST INT HUB       0
# WESTERN HUB        0
# dtype: int64

# %%
# Save the modified dataset as a new CSV file
save_path ='/content/drive/MyDrive/New_PJM_ML/KNN/df_all_2223_KNN'
df_all_2223.to_csv(save_path, index=False)

# %%
df_all_2223.head()
# Out:
#    AEP GEN HUB  AEP-DAYTON HUB  ATSI GEN HUB  CHICAGO GEN HUB  CHICAGO HUB  \
# 0    66.526689       68.095556     67.318277        65.559705    66.693074
# 1    73.990110       75.501068     74.708125        72.656474    73.844903
# 2    55.928728       56.996921     56.571705        54.765039    55.588311
# 3    52.131930       53.100233     52.694148        51.074570    51.790448
# 4    51.751316       52.390917     51.786250        49.386083    50.045211
#
#    DOMINION HUB  EASTERN HUB  N ILLINOIS HUB  NEW JERSEY HUB   OHIO HUB  \
# 0     69.495414    69.669366       66.248896       69.168388  68.268067
# 1     77.405280    77.793004       73.368035       77.122941  75.629564
# 2     58.358574    58.999558       55.258335       58.545221  57.086478
# 3     54.294922    54.701800       51.508351       54.240732  53.176826
# 4     53.740003    53.799772       49.809685       53.344182  52.374108
#
#    WEST INT HUB  WESTERN HUB
# 0     67.783333    68.755145
# 1     75.400555    76.753895
# 2     57.017916    58.048027
# 3     53.095880    53.991960
# 4     52.381388    53.275979

# %%
df_all_2223
# Out:
#       AEP GEN HUB  AEP-DAYTON HUB  ATSI GEN HUB  CHICAGO GEN HUB  CHICAGO HUB  \
# 0       66.526689       68.095556     67.318277        65.559705    66.693074
# 1       73.990110       75.501068     74.708125        72.656474    73.844903
# 2       55.928728       56.996921     56.571705        54.765039    55.588311
# 3       52.131930       53.100233     52.694148        51.074570    51.790448
# 4       51.751316       52.390917     51.786250        49.386083    50.045211
# ...           ...             ...           ...              ...          ...
# 8780    40.385504       41.826911     41.265341        40.868154    41.504461
# 8781    36.484737       37.688131     37.030644        36.783083    37.332459
# 8782    26.041513       26.862939     26.062576        26.412109    26.802300
# 8783    22.436031       23.111215     22.307936        22.598397    22.940277
# 8784    17.748531       18.123747     17.634527        16.499615    16.784425
#
#       DOMINION HUB  EASTERN HUB  N ILLINOIS HUB  NEW JERSEY HUB   OHIO HUB  \
# 0        69.495414    69.669366       66.248896       69.168388  68.268067
# 1        77.405280    77.793004       73.368035       77.122941  75.629564
# 2        58.358574    58.999558       55.258335       58.545221  57.086478
# 3        54.294922    54.701800       51.508351       54.240732  53.176826
# 4        53.740003    53.799772       49.809685       53.344182  52.374108
# ...            ...          ...             ...             ...        ...
# 8780     40.864404    38.182863       41.262732       38.245036  42.140567
# 8781     37.237394    35.006358       37.121669       34.942577  37.917976
# 8782     26.864957    22.804033       26.641553       23.194212  27.018790
# 8783     22.976768    20.179709       22.802370       20.341271  23.241002
# 8784     18.230117    17.152721       16.702347       17.095380  18.155619
#
#       WEST INT HUB  WESTERN HUB
# 0        67.783333    68.755145
# 1        75.400555    76.753895
# 2        57.017916    58.048027
# 3        53.095880    53.991960
# 4        52.381388    53.275979
# ...            ...          ...
# 8780     40.678797    40.893079
# 8781     36.739306    36.893853
# 8782     26.099814    26.064243
# 8783     22.339676    22.208324
# 8784     17.734213    17.675789
#
# [8785 rows x 12 columns]

# %% [markdown]
# ## **Deep Learning Part**

# %% [markdown]
# Deep Learning Methods:

# %% [markdown]
# # Gated Recurrent Units (GRUs)

# %% [markdown]
# ## Gated Recurrent Units (GRUs)

# %%
#GTU Data Set

# %%
df=df_all_2223

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

class GRUModel():
    def __init__(self, lookback, features, forecast):
        self.lookback = lookback
        self.features = features
        self.forecast = forecast

    def df(self, dataframe, lookback, features, forecast):
        df = dataframe.values
        # Create the X and y arrays
        self.X, self.y = [], []
        for i in range(self.lookback, len(df) - self.forecast):
            self.X.append(df[i - self.lookback:i])
            self.y.append(df[i:i + self.forecast, 0])  # USD feature

        # Reshape the X and y arrays
        self.X, self.y = np.array(self.X), np.array(self.y)
        self.X = np.reshape(self.X, (self.X.shape[0], self.X.shape[1], self.features))  # (batch_size, lookback, features)
        self.y = np.reshape(self.y, (self.y.shape[0], self.forecast))  # (batch_size, forecast)

        return self.X, self.y

    def create_model(self, l_rate, epoch, batchsize, x_train_data, y_train_data):
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=15,mode='min',restore_best_weights=True)

        gru_model = Sequential()
        gru_model.add(GRU(64, activation='relu', input_shape=(self.lookback, self.features)))
        gru_model.add(Dense(units=self.forecast))

        opt = tf.optimizers.Adam(learning_rate=l_rate)
        gru_model.compile(
            loss=tf.losses.MeanSquaredError(),
            optimizer=opt,
            metrics=[tf.metrics.MeanAbsoluteError()]
        )

        gru_history = gru_model.fit(
            x_train_data,
            y_train_data,
            epochs=epoch,
            batch_size=batchsize,
            verbose=1,
            validation_split=0.2,
            shuffle=False,
            callbacks=[early_stopping]
        )

        return gru_history, gru_model

# %%
gru = GRUModel(lookback=11, features=12, forecast=1)

# %%
X_all, y_all = gru.df(dataframe=df, lookback=11, features=12, forecast=1)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3, random_state=123)

# %%
history, model = gru.create_model(l_rate=0.001, epoch=300, batchsize=64, x_train_data=X_train, y_train_data=y_train)
# Out:
# Epoch 1/300
# 77/77 [==============================] - 4s 23ms/step - loss: 4829.7759 - mean_absolute_error: 17.1751 - val_loss: 533.6981 - val_mean_absolute_error: 12.3673
# Epoch 2/300
# 77/77 [==============================] - 1s 18ms/step - loss: 3885.1604 - mean_absolute_error: 15.3368 - val_loss: 507.2493 - val_mean_absolute_error: 11.7688
# Epoch 3/300
# 77/77 [==============================] - 1s 19ms/step - loss: 3959.3738 - mean_absolute_error: 15.8478 - val_loss: 659.1479 - val_mean_absolute_error: 14.9591
# Epoch 4/300
# 77/77 [==============================] - 1s 13ms/step - loss: 4167.2090 - mean_absolute_error: 16.4413 - val_loss: 1406.9783 - val_mean_absolute_error: 20.7559
# Epoch 5/300
# 77/77 [==============================] - 1s 13ms/step - loss: 5126.7046 - mean_absolute_error: 19.8008 - val_loss: 762.5808 - val_mean_absolute_error: 14.5256
# Epoch 6/300
# 77/77 [==============================] - 1s 11ms/step - loss: 3941.5117 - mean_absolute_error: 15.9027 - val_loss: 719.5820 - val_mean_absolute_error: 15.9133
# Epoch 7/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4469.9570 - mean_absolute_error: 15.8217 - val_loss: 653.8315 - val_mean_absolute_error: 14.2660
# Epoch 8/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4205.6562 - mean_absolute_error: 15.5152 - val_loss: 623.3517 - val_mean_absolute_error: 14.9935
# Epoch 9/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4420.1694 - mean_absolute_error: 16.2988 - val_loss: 762.3321 - val_mean_absolute_error: 18.4794
# Epoch 10/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4273.2339 - mean_absolute_error: 16.9777 - val_loss: 812.9094 - val_mean_absolute_error: 17.3659
# Epoch 11/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4279.7192 - mean_absolute_error: 16.5716 - val_loss: 786.1639 - val_mean_absolute_error: 16.4765
# Epoch 12/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4297.6650 - mean_absolute_error: 15.9029 - val_loss: 745.8814 - val_mean_absolute_error: 14.1398
# Epoch 13/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4352.4287 - mean_absolute_error: 17.5758 - val_loss: 985.5148 - val_mean_absolute_error: 16.0408
# Epoch 14/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4036.6646 - mean_absolute_error: 18.1504 - val_loss: 862.8726 - val_mean_absolute_error: 17.7040
# Epoch 15/300
# 77/77 [==============================] - 1s 16ms/step - loss: 4035.5974 - mean_absolute_error: 16.1086 - val_loss: 717.4934 - val_mean_absolute_error: 14.7905
# Epoch 16/300
# 77/77 [==============================] - 1s 18ms/step - loss: 4091.9902 - mean_absolute_error: 16.4736 - val_loss: 504.6542 - val_mean_absolute_error: 11.3528
# Epoch 17/300
# 77/77 [==============================] - 2s 20ms/step - loss: 3309.1367 - mean_absolute_error: 14.0921 - val_loss: 676.0698 - val_mean_absolute_error: 14.4401
# Epoch 18/300
# 77/77 [==============================] - 1s 16ms/step - loss: 3955.0410 - mean_absolute_error: 16.0559 - val_loss: 575.3605 - val_mean_absolute_error: 12.8328
# Epoch 19/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4040.8230 - mean_absolute_error: 15.4351 - val_loss: 919.5748 - val_mean_absolute_error: 12.6330
# Epoch 20/300
# 77/77 [==============================] - 1s 12ms/step - loss: 3875.3281 - mean_absolute_error: 17.2218 - val_loss: 861.0928 - val_mean_absolute_error: 18.2576
# Epoch 21/300
# 77/77 [==============================] - 1s 11ms/step - loss: 3847.7739 - mean_absolute_error: 16.3173 - val_loss: 918.3668 - val_mean_absolute_error: 18.1601
# Epoch 22/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4870.3027 - mean_absolute_error: 19.9350 - val_loss: 1592.5248 - val_mean_absolute_error: 23.6023
# Epoch 23/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4542.6470 - mean_absolute_error: 18.0077 - val_loss: 1205.3040 - val_mean_absolute_error: 17.2492
# Epoch 24/300
# 77/77 [==============================] - 1s 11ms/step - loss: 3796.3359 - mean_absolute_error: 16.6831 - val_loss: 953.9818 - val_mean_absolute_error: 14.3850
# Epoch 25/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4144.1982 - mean_absolute_error: 18.1713 - val_loss: 1317.0396 - val_mean_absolute_error: 18.1885
# Epoch 26/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4591.4355 - mean_absolute_error: 17.1717 - val_loss: 817.7661 - val_mean_absolute_error: 16.9399
# Epoch 27/300
# 77/77 [==============================] - 1s 11ms/step - loss: 4916.2300 - mean_absolute_error: 16.9776 - val_loss: 1264.7371 - val_mean_absolute_error: 13.5656
# Epoch 28/300
# 77/77 [==============================] - 1s 12ms/step - loss: 4247.4199 - mean_absolute_error: 19.6946 - val_loss: 765.6581 - val_mean_absolute_error: 16.4573
# Epoch 29/300
# 77/77 [==============================] - 1s 14ms/step - loss: 4298.6289 - mean_absolute_error: 17.9143 - val_loss: 1250.8761 - val_mean_absolute_error: 19.9085
# Epoch 30/300
# 77/77 [==============================] - 1s 19ms/step - loss: 4553.7661 - mean_absolute_error: 16.5797 - val_loss: 973.5084 - val_mean_absolute_error: 15.0243
# Epoch 31/300
# 77/77 [==============================] - 1s 18ms/step - loss: 4179.3784 - mean_absolute_error: 15.5119 - val_loss: 961.6851 - val_mean_absolute_error: 13.7155

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='GRUs - Training loss', linewidth=1, color='green')
    plt.plot(epochs, val_loss, 'r', label='GRUs - Validation loss', linewidth=1, color='purple')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(history, 'Training and validation loss')
# Out:
# <ipython-input-147-6b695fe83fa3>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'b', label='GRUs - Training loss', linewidth=1, color='green')
# <ipython-input-147-6b695fe83fa3>:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'r', label='GRUs - Validation loss', linewidth=1, color='purple')

# %%
plt.figure(figsize=(6,3))


plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs (LSTM Parametreleri ile) PJM 2022-2023 Haziran 24 Saat İlerisi Tahmin Grafiği")

hour= 24
n_day = 365
plot_day = hour*n_day

plt.plot(y_pred[:,-1], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test[:, -1], label='Gerçek', linewidth=1,color='purple')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 3))
y_pred_resized = y_pred[:, -1]
y_test_resized = y_test[:, -1]

plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs (LSTM Parametreleri ile) PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 30 Günlük")

hour = 24
n_day = 30
plot_day = hour * n_day
plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted', color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1, color='purple')

plt.legend()
plt.show()
# Out:
# 83/83 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs(w LSTM parameters)-PJM 2022-2023 June 24 h Ahead Prediction, 30 Days")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 3))
y_pred_resized = y_pred[:, -1]
y_test_resized = y_test[:, -1]

plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs (LSTM Parametreleri ile) PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 5 Günlük")

hour = 24
n_day = 5
plot_day = hour * n_day
plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted', color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1, color='purple')

plt.legend()
plt.show()
# Out:
# 83/83 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs(w LSTM parameters)-PJM 2022-2023 June 24 h Ahead Prediction, 5 Days")

hour= 24
n_day = 5
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 3))
y_pred_resized = y_pred[:, -1]
y_test_resized = y_test[:, -1]

plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs (LSTM Parametreleri ile) PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 1 Günlük")

hour = 24
n_day = 1
plot_day = hour * n_day
plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted', color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1, color='purple')

plt.legend()
plt.show()
# Out:
# 83/83 [==============================] - 0s 5ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("GRUs(w LSTM parameters)-PJM 2022-2023 June 24 h Ahead Prediction, 1 Day")

hour= 24
n_day = 1
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

errors = y_pred - y_test
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()

print('Mean Absolute Error: {:.2f}'.format(mae))
print('Root Mean Square Error: {:.2f}'.format(rmse))
print('R2 Score: ', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 13.76
# Root Mean Square Error: 55.18
# R2 Score:  0.7648650940933309
