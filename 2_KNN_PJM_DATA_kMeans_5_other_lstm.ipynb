# %% [markdown]
# <a href="https://colab.research.google.com/github/ersozbasak/Machine-Learning-Regression-Models/blob/master/2_KNN_PJM_DATA_kMeans_5_other_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
from sklearn import metrics # for the evaluation
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import gc
import sys
#mpl.rcParams['figure.figsize'] = (17, 5)
#mpl.rcParams['axes.grid'] = False
#sns.set_style("whitegrid")
from pandas import DataFrame , concat
from sklearn.metrics import mean_absolute_error , mean_squared_error
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from numpy import mean , concatenate
from math import sqrt
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation,Dropout
from numpy import array , hstack
from tensorflow import keras
import tensorflow as tf
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/New_PJM_ML/kMeans
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/1KIngltLQmHhYc3ztZl6sVXvAe_rP7VvU/New_PJM_ML/kMeans
#  autokeras/
#  clustering_comparison.csv
#  dataset_km5_largest.pkl
#  dataset_km5_others.pkl
#  dataset.pkl
#  history_lstm_all_0.708.pkl
#  history_lstm_all_0.716.pkl
#  history_lstm_all_0.756.pkl
#  history_lstm_all_0.796.pkl
#  history_lstm_all.pkl
#  history_lstm_km5_largest_0.738.pkl
#  history_lstm_km5_largest_0.748.pkl
#  history_lstm_km5_largest_0.767.pkl
#  history_lstm_km5_largest.pkl
#  history_lstm_km5_others_0.574.pkl
#  history_lstm_km5_others_0.592.pkl
#  history_lstm_km5_others.pkl
#  kMeans_5_3d_0.png
#  kMeans_5_3d_11.png
#  kMeans_5_3d_12.png
#  kMeans_5_3d_13.png
#  kMeans_5_3d_14.png
#  kMeans_5_3d_1.png
#  kMeans_5_3d_2.png
#  kMeans_5_3d_3.png
#  kMeans_5_3d_4.png
# 'kMeans_5_3d_random4_4_4_AEP-DAYTON HUB_CHICAGO HUB.svg'
# 'kMeans_5_3d_random4_4_4_AEP GEN HUB_ATSI GEN HUB.svg'
# 'kMeans_5_3d_random4_4_4_AEP GEN HUB_CHICAGO HUB.svg'
# 'kMeans_5_3d_random4_4_4_ATSI GEN HUB_DOMINION HUB.svg'
# 'kMeans_5_3d_random4_4_4_DOMINION HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_4_4_EASTERN HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_5_5_AEP GEN HUB_AEP-DAYTON HUB.svg'
# 'kMeans_5_3d_random4_5_5_AEP GEN HUB_ATSI GEN HUB.svg'
# 'kMeans_5_3d_random4_5_5_ATSI GEN HUB_CHICAGO HUB.svg'
# 'kMeans_5_3d_random4_5_5_CHICAGO HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_6_6AEP GEN HUB_AEP-DAYTON HUB.svg'
# 'kMeans_5_3d_random4_6_6AEP GEN HUB_CHICAGO HUB.svg'
# 'kMeans_5_3d_random4_6_6CHICAGO HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_6_6DOMINION HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_AEP-DAYTON HUB_CHICAGO GEN HUB.svg'
# 'kMeans_5_3d_random4_AEP-DAYTON HUB_CHICAGO HUB.svg'
# 'kMeans_5_3d_random4_AEP-DAYTON HUB_DOMINION HUB.svg'
# 'kMeans_5_3d_random4_AEP-DAYTON HUB_NEW JERSEY HUB.svg'
# 'kMeans_5_3d_random4_AEP-DAYTON HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_AEP GEN HUB_AEP-DAYTON HUB.svg'
# 'kMeans_5_3d_random4_AEP GEN HUB_ATSI GEN HUB.svg'
# 'kMeans_5_3d_random4_AEP GEN HUB_CHICAGO GEN HUB.svg'
# 'kMeans_5_3d_random4_AEP GEN HUB_EASTERN HUB.svg'
# 'kMeans_5_3d_random4_AEP GEN HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_ATSI GEN HUB_CHICAGO GEN HUB.svg'
# 'kMeans_5_3d_random4_ATSI GEN HUB_DOMINION HUB.svg'
# 'kMeans_5_3d_random4_CHICAGO GEN HUB_NEW JERSEY HUB.svg'
# 'kMeans_5_3d_random4_CHICAGO GEN HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_CHICAGO HUB_N ILLINOIS HUB.svg'
# 'kMeans_5_3d_random4_DOMINION HUB_EASTERN HUB.svg'
# 'kMeans_5_3d_random4_EASTERN HUB_NEW JERSEY HUB.svg'
# 'kMeans_5_3d_random4_N ILLINOIS HUB_NEW JERSEY HUB.svg'
#  kMeans_5_3d_random4.svg
#  kMeans_5_largest_cluster.csv
#  kmeans_5_model_backup_6696.pkl
#  kmeans_5_model.pkl
#  kMeans_5_other_clusters.csv
# 'kMeans_5_random4AEP-DAYTON HUBCHICAGO HUB.svg'
# 'kMeans_5_random4AEP-DAYTON HUBDOMINION HUB.svg'
# 'kMeans_5_random4AEP-DAYTON HUBEASTERN HUB.svg'
# 'kMeans_5_random4AEP-DAYTON HUBN ILLINOIS HUB.svg'
# 'kMeans_5_random4AEP GEN HUBAEP-DAYTON HUB.svg'
# 'kMeans_5_random4AEP GEN HUBATSI GEN HUB.svg'
# 'kMeans_5_random4AEP GEN HUBCHICAGO GEN HUB.svg'
# 'kMeans_5_random4AEP GEN HUBDOMINION HUB.svg'
# 'kMeans_5_random4AEP GEN HUBEASTERN HUB.svg'
# 'kMeans_5_random4AEP GEN HUBNEW JERSEY HUB.svg'
# 'kMeans_5_random4AEP GEN HUBN ILLINOIS HUB.svg'
# 'kMeans_5_random4AEP GEN HUBOHIO HUB.svg'
# 'kMeans_5_random4ATSI GEN HUBDOMINION HUB.svg'
# 'kMeans_5_random4ATSI GEN HUBEASTERN HUB.svg'
# 'kMeans_5_random4ATSI GEN HUBNEW JERSEY HUB.svg'
# 'kMeans_5_random4ATSI GEN HUBN ILLINOIS HUB.svg'
# 'kMeans_5_random4ATSI GEN HUBOHIO HUB.svg'
# 'kMeans_5_random4ATSI GEN HUBWEST INT HUB.svg'
# 'kMeans_5_random4CHICAGO GEN HUBOHIO HUB.svg'
# 'kMeans_5_random4CHICAGO GEN HUBWEST INT HUB.svg'
# 'kMeans_5_random4CHICAGO HUBDOMINION HUB.svg'
# 'kMeans_5_random4CHICAGO HUBNEW JERSEY HUB.svg'
# 'kMeans_5_random4CHICAGO HUBN ILLINOIS HUB.svg'
# 'kMeans_5_random4CHICAGO HUBOHIO HUB.svg'
# 'kMeans_5_random4CHICAGO HUBWEST INT HUB.svg'
# 'kMeans_5_random4DOMINION HUBOHIO HUB.svg'
# 'kMeans_5_random4DOMINION HUBWEST INT HUB.svg'
# 'kMeans_5_random4EASTERN HUBNEW JERSEY HUB.svg'
# 'kMeans_5_random4NEW JERSEY HUBOHIO HUB.svg'
# 'kMeans_5_random4NEW JERSEY HUBWEST INT HUB.svg'
# 'kMeans_5_random4N ILLINOIS HUBNEW JERSEY HUB.svg'
# 'kMeans_5_random4OHIO HUBWEST INT HUB.svg'
#  kMeans_5_random4.svg
# 'kMeans_loss_comparison_k-Means, k=5 Largest Cluster.svg'
# 'kMeans_loss_comparison_k-Means, k=5 Others.svg'
#  kMeans_loss_comparison.svg
# 'kMeans_loss_comparison_Whole Data Set.svg'
#  kMeans_prediction_-1_comparison.svg
# 'kMeans_prediction_24_1_comparison_k-Means k=5 Largest Cluster.svg'
# 'kMeans_prediction_24_1_comparison_k-Means, k=5 Largest Cluster.svg'
# 'kMeans_prediction_24_1_comparison_k-Means k=5 Others.svg'
# 'kMeans_prediction_24_1_comparison_k-Means, k=5 Others.svg'
# 'kMeans_prediction_24_1_comparison_Whole Data Set.svg'
# 'kMeans_prediction_24_30_comparison_k-Means, k=5 Largest Cluster.svg'
# 'kMeans_prediction_24_30_comparison_k-Means, k=5 Others.svg'
# 'kMeans_prediction_24_30_comparison_k-Means, k=5 Remaining Clusters.svg'
# 'kMeans_prediction_24_30_comparison_Whole Data Set.svg'
# 'kMeans_prediction_24_5_comparison_k-Means k=5 Largest Cluster.svg'
# 'kMeans_prediction_24_5_comparison_k-Means, k=5 Largest Cluster.svg'
# 'kMeans_prediction_24_5_comparison_k-Means k=5 Others.svg'
# 'kMeans_prediction_24_5_comparison_k-Means, k=5 Others.svg'
# 'kMeans_prediction_24_5_comparison_Whole Data Set.svg'
#  kMeans_prediction_24h_5day_comparison.svg
#  kMeans_prediction_24h_comparison.svg
#  kMeans_prediction_500_comparison.svg
#  metrics_table.csv
#  model_lstm_all_0.708.pkl
#  model_lstm_all_0.756.pkl
#  model_lstm_all_0.796.pkl
#  model_lstm_all.pkl
#  model_lstm_km5_largest_0.738.pkl
#  model_lstm_km5_largest_0.748.pkl
#  model_lstm_km5_largest_0.767.pkl
#  model_lstm_km5_largest.pkl
#  model_lstm_km5_others_0.592.pkl
#  model_lstm_km5_others.pkl
#  pjm_dataset_all.csv

# %%
import pandas as pd

# Read the CSV file into a DataFrame
other_clusters_df = pd.read_csv('kMeans_5_other_clusters.csv')

# Print the DataFrame
other_clusters_df
# Out:
#       AEP GEN HUB  AEP-DAYTON HUB  ATSI GEN HUB  CHICAGO GEN HUB  CHICAGO HUB  \
# 0       73.990110       75.501068     74.708125        72.656474    73.844903
# 1       76.573465       78.252597     77.712367        74.400116    75.496752
# 2       82.648465       85.195786     84.264754        73.618795    74.722071
# 3       92.583597       94.955496     92.876818        90.709308    92.078144
# 4      150.496645      154.096246    148.319886       146.195981   148.304074
# 2087    88.880022       90.363498     84.703807        86.342539    87.173342
# 2088    70.414518       73.104999     72.734432        71.123513    72.302938
#
#       DOMINION HUB  EASTERN HUB  N ILLINOIS HUB  NEW JERSEY HUB    OHIO HUB  \
# 0        77.405280    77.793004       73.368035       77.122941   75.629564
# 1        78.669352    79.446832       75.057755       78.141460   78.418630
# 2        83.975634    82.890285       74.310410       81.973574   85.611173
# 3        97.192150    67.127958       91.514179       71.464949   95.176779
# 4       164.739272    61.643579      147.459035       77.256038  154.155452
# ...            ...          ...             ...             ...         ...
# 2084     89.101753    22.086949       77.824652       34.948573   82.855061
# 2085    175.064520    27.007870      151.765050       55.523406  156.806313
# 2086    100.743364    20.541222       87.283071       35.791799   90.856234
# 2087    100.464710     6.415167       86.820300       23.225172   90.295597
# 2088     69.461888    72.192073       71.867898       71.610881   73.680330
#
#       WEST INT HUB  WESTERN HUB
# 0        75.400555    76.753895
# 1        77.952408    79.320448
# 2        84.123566    85.334605
# 3        94.732916    96.007386
# 4       155.071938   157.473387
# ...            ...          ...
# 2084     78.251932    82.025101
# 2085    158.960819   161.019879
# 2086     91.144158    93.034230
# 2087     91.102816    91.149505
# 2088     71.207595    71.912393
#
# [2089 rows x 12 columns]

# %%
class LSTM():
    def __init__(self, lookback, features, forecast):
        self.lookback = lookback
        self.features = features
        self.forecast = forecast


    def df(self, dataframe, lookback, features, forecast):
        df = dataframe.values
        # Create the X and y arrays
        self.X, self.y = [], []
        for i in range(self.lookback, len(df) - self.forecast):
            self.X.append(df[i-self.lookback:i])
            self.y.append(df[i:i+self.forecast, 0]) # USD feature

      # Reshape the X and y arrays
        self.X, self.y = np.array(self.X), np.array(self.y)
        self.X = np.reshape(self.X, (self.X.shape[0], self.X.shape[1], self.features)) # (batch_size, lookback, features)
        self.y = np.reshape(self.y, (self.y.shape[0], self.forecast)) # (batch_size, forecast)

        return self.X, self.y

# %%
lstm = LSTM(lookback=11, features=12, forecast=1)

# %%
X_all, y_all = lstm.df(dataframe = df, lookback = 11, features = 12, forecast = 1)

# %%
X_all
# Out:
# array([[[ 73.99011 ,  75.501068,  74.708125, ...,  75.629564,
#           75.400555,  76.753895],
#         [ 76.573465,  78.252597,  77.712367, ...,  78.41863 ,
#           77.952408,  79.320448],
#         [ 82.648465,  85.195786,  84.264754, ...,  85.611173,
#           84.123566,  85.334605],
#         ...,
#         [107.261645, 127.988973, 108.298106, ..., 138.463403,
#          111.482079, 113.62548 ],
#         [146.914956, 168.417395, 147.726591, ..., 178.795298,
#          152.892818, 156.232523],
#         [131.257741, 152.42921 , 131.326818, ..., 162.778231,
#          136.896151, 140.509242]],
#
#        [[ 76.573465,  78.252597,  77.712367, ...,  78.41863 ,
#           77.952408,  79.320448],
#         [ 82.648465,  85.195786,  84.264754, ...,  85.611173,
#           84.123566,  85.334605],
#         [ 92.583597,  94.955496,  92.876818, ...,  95.176779,
#           94.732916,  96.007386],
#         ...,
#         [146.914956, 168.417395, 147.726591, ..., 178.795298,
#          152.892818, 156.232523],
#         [131.257741, 152.42921 , 131.326818, ..., 162.778231,
#          136.896151, 140.509242],
#         [116.114035, 137.266055, 116.414943, ..., 147.73295 ,
#          121.179947, 124.824192]],
#
#        [[ 82.648465,  85.195786,  84.264754, ...,  85.611173,
#           84.123566,  85.334605],
#         [ 92.583597,  94.955496,  92.876818, ...,  95.176779,
#           94.732916,  96.007386],
#         [150.496645, 154.096246, 148.319886, ..., 154.155452,
#          155.071938, 157.473387],
#         ...,
#         [131.257741, 152.42921 , 131.326818, ..., 162.778231,
#          136.896151, 140.509242],
#         [116.114035, 137.266055, 116.414943, ..., 147.73295 ,
#          121.179947, 124.824192],
#         [114.711645, 126.773004, 109.762216, ..., 132.894545,
#          117.323879, 121.581909]],
#
#        ...,
#
#        [[ 90.519956,  91.933152,  87.931023, ...,  91.751893,
#           95.628787,  95.619411],
#         [ 99.039825, 100.561766,  98.403333, ..., 100.440926,
#          102.86481 , 103.907242],
#         [ 76.454013,  77.478714,  76.200644, ...,  77.371526,
#           78.46884 ,  80.328169],
#         ...,
#         [116.510724, 117.647695, 112.186951, ..., 117.450256,
#          120.05337 , 121.517847],
#         [ 94.263004,  96.238238,  82.107746, ...,  96.594787,
#           91.754942,  95.448868],
#         [ 80.846053,  82.532516,  68.005568, ...,  82.855061,
#           78.251932,  82.025101]],
#
#        [[ 99.039825, 100.561766,  98.403333, ..., 100.440926,
#          102.86481 , 103.907242],
#         [ 76.454013,  77.478714,  76.200644, ...,  77.371526,
#           78.46884 ,  80.328169],
#         [ 72.72136 ,  74.12559 ,  74.304413, ...,  74.229557,
#           73.850741,  75.025171],
#         ...,
#         [ 94.263004,  96.238238,  82.107746, ...,  96.594787,
#           91.754942,  95.448868],
#         [ 80.846053,  82.532516,  68.005568, ...,  82.855061,
#           78.251932,  82.025101],
#         [155.272456, 157.192907, 148.668807, ..., 156.806313,
#          158.960819, 161.019879]],
#
#        [[ 76.454013,  77.478714,  76.200644, ...,  77.371526,
#           78.46884 ,  80.328169],
#         [ 72.72136 ,  74.12559 ,  74.304413, ...,  74.229557,
#           73.850741,  75.025171],
#         [109.208597, 110.008813, 103.856345, ..., 109.714011,
#          112.658693, 115.465803],
#         ...,
#         [ 80.846053,  82.532516,  68.005568, ...,  82.855061,
#           78.251932,  82.025101],
#         [155.272456, 157.192907, 148.668807, ..., 156.806313,
#          158.960819, 161.019879],
#         [ 89.814693,  91.065472,  84.560758, ...,  90.856234,
#           91.144158,  93.03423 ]]])

# %%
y_all
# Out:
# array([[116.114035],
#        [114.711645],
#        [118.818969],
#        ...,
#        [155.272456],
#        [ 89.814693],
#        [ 88.880022]])

# %%
print("X_all shape : {}".format(X_all.shape))
print("y_all shape : {}".format(y_all.shape))
# Out:
# X_all shape : (2077, 11, 12)
# y_all shape : (2077, 1)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3,random_state=123)

# %%
import pickle

# Create a dictionary to store the datasets
dataset = {
    'X_train': X_train,
    'X_test': X_test,
    'y_train': y_train,
    'y_test': y_test
}

# Export the dataset using pickle
with open('dataset_km5_others.pkl', 'wb') as file:
    pickle.dump(dataset, file)

# %%
print(y_all.max())
print(X_all.max())
print(y_all.min())
print(X_all.min())

print(np.mean(y_all))
print(np.mean(X_all))
# Out:
# 3761.41375
# 4360.850238
# 28.635855
# -22.492587
# 124.46977221665864
# 124.578689184758

# %%
print("X_train shape : {}".format(X_train.shape))
print("y_train shape : {}".format(y_train.shape))
print("X_test shape : {}".format(X_test.shape))
print("y_test shape : {}".format(y_test.shape))
# Out:
# X_train shape : (1453, 11, 12)
# y_train shape : (1453, 1)
# X_test shape : (624, 11, 12)
# y_test shape : (624, 1)

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
def create_model(l_rate, epoch, batchsize, x_train_data, y_train_data):

  #early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=15,mode='min', restore_best_weights=True)#ceed
  lstm_model = tf.keras.Sequential()
  #lstm_model.add(tf.keras.layers.LSTM(256,activation='relu',input_shape=(lstm.lookback, lstm.features),return_sequences=True))
  #lstm_model.add(tf.keras.layers.LSTM(128,activation='relu',input_shape=(lstm.lookback, lstm.features),return_sequences=True))
  #lstm_model.add(tf.keras.layers.LSTM(64,activation='relu',input_shape=(lstm.lookback, lstm.features),return_sequences=True))
  lstm_model.add(tf.keras.layers.LSTM(64,activation='relu'))
  lstm_model.add(tf.keras.layers.Dense(units=lstm.forecast))

  opt = tf.optimizers.Adam(learning_rate=l_rate)
  lstm_model.compile(
    loss=tf.losses.MeanSquaredError(),
    optimizer=opt,
    metrics=[tf.metrics.MeanAbsoluteError()]
    )

  lstm_history = lstm_model.fit(x_train_data, y_train_data,
    epochs=epoch,
    batch_size = batchsize,
    verbose=1,
    validation_split = 0.2,
    shuffle=False,
    #callbacks = [early_stopping]
    )

  return lstm_history, lstm_model

# %%
history, model = create_model(l_rate = 0.001, epoch = 300, batchsize = 64, x_train_data = X_train, y_train_data = y_train)
# Out:
# Epoch 1/300
# 19/19 [==============================] - 3s 30ms/step - loss: 35658.7773 - mean_absolute_error: 77.3848 - val_loss: 52045.7578 - val_mean_absolute_error: 53.9648
# Epoch 2/300
# 19/19 [==============================] - 0s 14ms/step - loss: 29836.2969 - mean_absolute_error: 59.9031 - val_loss: 41045.7969 - val_mean_absolute_error: 84.5842
# Epoch 3/300
# 19/19 [==============================] - 0s 13ms/step - loss: 19577.2070 - mean_absolute_error: 62.3257 - val_loss: 42849.1289 - val_mean_absolute_error: 55.0310
# Epoch 4/300
# 19/19 [==============================] - 0s 13ms/step - loss: 24850.1309 - mean_absolute_error: 51.7813 - val_loss: 37451.5469 - val_mean_absolute_error: 47.4788
# Epoch 5/300
# 19/19 [==============================] - 0s 13ms/step - loss: 18289.0410 - mean_absolute_error: 45.7840 - val_loss: 37602.5000 - val_mean_absolute_error: 38.1286
# Epoch 6/300
# 19/19 [==============================] - 0s 13ms/step - loss: 13818.8477 - mean_absolute_error: 39.0691 - val_loss: 39520.1211 - val_mean_absolute_error: 41.8191
# Epoch 7/300
# 19/19 [==============================] - 0s 12ms/step - loss: 14484.5850 - mean_absolute_error: 40.5615 - val_loss: 40905.4805 - val_mean_absolute_error: 41.1336
# Epoch 8/300
# 19/19 [==============================] - 0s 15ms/step - loss: 13181.4131 - mean_absolute_error: 36.3178 - val_loss: 40963.1289 - val_mean_absolute_error: 42.0559
# Epoch 9/300
# 19/19 [==============================] - 0s 13ms/step - loss: 10934.2461 - mean_absolute_error: 34.6274 - val_loss: 34896.5273 - val_mean_absolute_error: 42.3607
# Epoch 63/300
# 19/19 [==============================] - 0s 13ms/step - loss: 12041.3193 - mean_absolute_error: 36.1015 - val_loss: 35063.0703 - val_mean_absolute_error: 41.4448
# Epoch 64/300
# 19/19 [==============================] - 0s 13ms/step - loss: 12699.5684 - mean_absolute_error: 35.9345 - val_loss: 34298.5469 - val_mean_absolute_error: 38.6637
# Epoch 65/300
# 19/19 [==============================] - 0s 13ms/step - loss: 12039.7969 - mean_absolute_error: 35.0896 - val_loss: 35708.9141 - val_mean_absolute_error: 45.1112
# Epoch 66/300
# 19/19 [==============================] - 0s 13ms/step - loss: 11382.9004 - mean_absolute_error: 35.4396 - val_loss: 35551.6680 - val_mean_absolute_error: 38.1129
# Epoch 67/300
# 19/19 [==============================] - 0s 14ms/step - loss: 9833.4121 - mean_absolute_error: 30.2967 - val_loss: 35798.6680 - val_mean_absolute_error: 35.3887
# Epoch 68/300
# 19/19 [==============================] - 0s 12ms/step - loss: 9802.5830 - mean_absolute_error: 29.7946 - val_loss: 35961.7852 - val_mean_absolute_error: 35.9500
# Epoch 69/300
# 19/19 [==============================] - 0s 14ms/step - loss: 9519.7305 - mean_absolute_error: 29.3594 - val_loss: 35984.7812 - val_mean_absolute_error: 36.3090
# Epoch 70/300
# 19/19 [==============================] - 0s 12ms/step - loss: 9470.0732 - mean_absolute_error: 29.4880 - val_loss: 35960.8633 - val_mean_absolute_error: 36.3025
# Epoch 71/300
# 19/19 [==============================] - 0s 12ms/step - loss: 9564.7305 - mean_absolute_error: 29.6738 - val_loss: 35901.1562 - val_mean_absolute_error: 36.1917
# Epoch 72/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9674.8525 - mean_absolute_error: 30.0345 - val_loss: 36316.3984 - val_mean_absolute_error: 36.9331
# Epoch 73/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9781.8027 - mean_absolute_error: 30.2939 - val_loss: 36228.3359 - val_mean_absolute_error: 36.5869
# Epoch 74/300
# 19/19 [==============================] - 0s 12ms/step - loss: 9763.9316 - mean_absolute_error: 30.1724 - val_loss: 36201.9844 - val_mean_absolute_error: 36.5910
# Epoch 75/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9731.5762 - mean_absolute_error: 30.0563 - val_loss: 36116.7188 - val_mean_absolute_error: 36.4483
# Epoch 76/300
# 19/19 [==============================] - 0s 15ms/step - loss: 9698.0020 - mean_absolute_error: 29.9674 - val_loss: 36002.2305 - val_mean_absolute_error: 36.0618
# Epoch 77/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9672.5117 - mean_absolute_error: 29.8778 - val_loss: 35937.4336 - val_mean_absolute_error: 35.8347
# Epoch 78/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9635.8037 - mean_absolute_error: 29.6972 - val_loss: 35878.2266 - val_mean_absolute_error: 35.7123
# Epoch 79/300
# 19/19 [==============================] - 0s 14ms/step - loss: 9609.4746 - mean_absolute_error: 29.6525 - val_loss: 35827.2891 - val_mean_absolute_error: 35.6187
# Epoch 80/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9581.4863 - mean_absolute_error: 29.5953 - val_loss: 35786.3594 - val_mean_absolute_error: 35.5483
# Epoch 81/300
# 19/19 [==============================] - 0s 14ms/step - loss: 9552.2686 - mean_absolute_error: 29.5221 - val_loss: 35745.2344 - val_mean_absolute_error: 35.4663
# Epoch 82/300
# 19/19 [==============================] - 0s 13ms/step - loss: 
300
# 19/19 [==============================] - 0s 13ms/step - loss: 9215.4785 - mean_absolute_error: 27.9215 - val_loss: 33524.1992 - val_mean_absolute_error: 32.4730
# Epoch 162/300
# 19/19 [==============================] - 0s 14ms/step - loss: 9148.3408 - mean_absolute_error: 27.8858 - val_loss: 33486.6133 - val_mean_absolute_error: 32.3705
# Epoch 163/300
# 19/19 [==============================] - 0s 13ms/step - loss: 9051.8662 - mean_absolute_error: 27.7812 - val_loss: 33462.8125 - val_mean_absolute_error: 32.3501
# Epoch 164/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8971.8027 - mean_absolute_error: 27.8462 - val_loss: 33469.8164 - val_mean_absolute_error: 32.4403
# Epoch 165/300
# 19/19 [==============================] - 0s 15ms/step - loss: 8867.3389 - mean_absolute_error: 27.9093 - val_loss: 33448.4609 - val_mean_absolute_error: 32.4245
# Epoch 166/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8803.1494 - mean_absolute_error: 27.8597 - val_loss: 33424.5820 - val_mean_absolute_error: 32.4737
# Epoch 167/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8739.6934 - mean_absolute_error: 27.7662 - val_loss: 33409.7461 - val_mean_absolute_error: 32.6246
# Epoch 168/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8705.5400 - mean_absolute_error: 27.7715 - val_loss: 33366.5938 - val_mean_absolute_error: 32.5175
# Epoch 169/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8666.2480 - mean_absolute_error: 27.6789 - val_loss: 33292.4648 - val_mean_absolute_error: 32.6487
# Epoch 170/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8597.0449 - mean_absolute_error: 27.8209 - val_loss: 33276.1172 - val_mean_absolute_error: 32.6739
# Epoch 171/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8513.4023 - mean_absolute_error: 27.6491 - val_loss: 33274.7305 - val_mean_absolute_error: 32.6116
# Epoch 172/300
# 19/19 [==============================] - 0s 15ms/step - loss: 8557.4365 - mean_absolute_error: 27.7062 - val_loss: 33267.9023 - val_mean_absolute_error: 32.7790
# Epoch 173/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8491.9619 - mean_absolute_error: 27.9324 - val_loss: 33422.4805 - val_mean_absolute_error: 32.9355
# Epoch 174/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8438.6260 - mean_absolute_error: 27.8869 - val_loss: 33473.7852 - val_mean_absolute_error: 32.9248
# Epoch 175/300
# 19/19 [==============================] - 0s 15ms/step - loss: 8398.0078 - mean_absolute_error: 27.9147 - val_loss: 33486.5273 - val_mean_absolute_error: 33.2084
# Epoch 176/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8355.6592 - mean_absolute_error: 27.9470 - val_loss: 33459.0547 - val_mean_absolute_error: 33.2000
# Epoch 177/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8301.6475 - mean_absolute_error: 27.8200 - val_loss: 33445.4023 - val_mean_absolute_error: 33.1625
# Epoch 178/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8249.7256 - mean_absolute_error: 27.7805 - val_loss: 33432.8633 - val_mean_absolute_error: 33.1871
# Epoch 179/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8192.2617 - mean_absolute_error: 27.7491 - val_loss: 33413.3711 - val_mean_absolute_error: 33.4357
# Epoch 180/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8155.5054 - mean_absolute_error: 27.8707 - val_loss: 33356.1680 - val_mean_absolute_error: 33.3626
# Epoch 181/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8095.9277 - mean_absolute_error: 27.6660 - val_loss: 33272.5586 - val_mean_absolute_error: 33.2754
# Epoch 182/300
# 19/19 [==============================] - 0s 13ms/step - loss: 8052.5767 - mean_absolute_error: 27.5818 - val_loss: 33218.4531 - val_mean_absolute_error: 33.2086
# Epoch 183/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8104.3398 - mean_absolute_error: 27.8197 - val_loss: 33164.0039 - val_mean_absolute_error: 33.0000
# Epoch 184/300
# 19/19 [==============================] - 0s 13ms/step - loss: 
300
# 19/19 [==============================] - 0s 14ms/step - loss: 7323.7822 - mean_absolute_error: 27.2976 - val_loss: 33076.0547 - val_mean_absolute_error: 33.4060
# Epoch 204/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7273.8193 - mean_absolute_error: 27.2436 - val_loss: 33087.2031 - val_mean_absolute_error: 33.3073
# Epoch 205/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7285.8784 - mean_absolute_error: 27.1901 - val_loss: 33046.0156 - val_mean_absolute_error: 33.1844
# Epoch 206/300
# 19/19 [==============================] - 0s 16ms/step - loss: 7206.3784 - mean_absolute_error: 27.1027 - val_loss: 33113.4492 - val_mean_absolute_error: 33.2977
# Epoch 207/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8320.7432 - mean_absolute_error: 28.2966 - val_loss: 32314.2949 - val_mean_absolute_error: 35.4266
# Epoch 208/300
# 19/19 [==============================] - 0s 13ms/step - loss: 12142.0742 - mean_absolute_error: 38.3019 - val_loss: 34989.5547 - val_mean_absolute_error: 42.2434
# Epoch 209/300
# 19/19 [==============================] - 0s 14ms/step - loss: 8360.9375 - mean_absolute_error: 36.4061 - val_loss: 34441.2695 - val_mean_absolute_error: 38.1751
# Epoch 210/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7787.3794 - mean_absolute_error: 32.6550 - val_loss: 33902.4062 - val_mean_absolute_error: 37.5404
# Epoch 211/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7492.8555 - mean_absolute_error: 31.2398 - val_loss: 33565.9531 - val_mean_absolute_error: 37.1381
# Epoch 212/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7911.3135 - mean_absolute_error: 30.9852 - val_loss: 33451.2734 - val_mean_absolute_error: 35.9624
# Epoch 213/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7735.9321 - mean_absolute_error: 30.3457 - val_loss: 33265.7656 - val_mean_absolute_error: 34.8729
# Epoch 214/300
# 19/19 [==============================] - 0s 16ms/step - loss: 7518.3013 - mean_absolute_error: 29.8730 - val_loss: 33494.5117 - val_mean_absolute_error: 35.7074
# Epoch 215/300
# 19/19 [==============================] - 0s 16ms/step - loss: 7502.6479 - mean_absolute_error: 30.0407 - val_loss: 33590.1641 - val_mean_absolute_error: 35.2799
# Epoch 216/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7472.3975 - mean_absolute_error: 30.0772 - val_loss: 33611.0742 - val_mean_absolute_error: 35.4945
# Epoch 217/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7546.3975 - mean_absolute_error: 30.8088 - val_loss: 33776.3516 - val_mean_absolute_error: 37.5993
# Epoch 218/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7466.9751 - mean_absolute_error: 30.3819 - val_loss: 33519.0195 - val_mean_absolute_error: 35.1780
# Epoch 219/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7281.5532 - mean_absolute_error: 29.1913 - val_loss: 33414.6289 - val_mean_absolute_error: 34.6742
# Epoch 220/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7303.4390 - mean_absolute_error: 30.1152 - val_loss: 33532.1680 - val_mean_absolute_error: 35.9075
# Epoch 221/300
# 19/19 [==============================] - 0s 15ms/step - loss: 7276.1143 - mean_absolute_error: 29.3433 - val_loss: 33361.1992 - val_mean_absolute_error: 34.4542
# Epoch 222/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7186.4492 - mean_absolute_error: 29.0194 - val_loss: 33411.3008 - val_mean_absolute_error: 34.8948
# Epoch 223/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7290.9810 - mean_absolute_error: 29.2096 - val_loss: 33414.1055 - val_mean_absolute_error: 34.8416
# Epoch 224/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7243.2529 - mean_absolute_error: 28.7724 - val_loss: 33396.5430 - val_mean_absolute_error: 34.4744
# Epoch 225/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7139.9429 - mean_absolute_error: 28.5780 - val_loss: 33408.3789 - val_mean_absolute_error: 34.4484
# Epoch 226/300
# 19/19 [==============================] - 0s 15ms/step - loss: 7060.9395 - mean_absolute_error: 28.2669 - val_loss: 33982.0273 - val_mean_absolute_error: 35.1428
# Epoch 227/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6965.7153 - mean_absolute_error: 28.1158 - val_loss: 33477.3867 - val_mean_absolute_error: 34.5613
# Epoch 228/300
# 19/19 [==============================] - 0s 15ms/step - loss: 7250.5913 - mean_absolute_error: 28.8653 - val_loss: 34022.9766 - val_mean_absolute_error: 35.6911
# Epoch 229/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7870.6860 - mean_absolute_error: 30.3132 - val_loss: 32971.8398 - val_mean_absolute_error: 35.0201
# Epoch 230/300
# 19/19 [==============================] - 0s 15ms/step - loss: 7591.5420 - mean_absolute_error: 30.8189 - val_loss: 33537.0781 - val_mean_absolute_error: 35.3862
# Epoch 231/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7628.5498 - mean_absolute_error: 30.2680 - val_loss: 34221.7578 - val_mean_absolute_error: 35.3961
# Epoch 232/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7048.9023 - mean_absolute_error: 29.3105 - val_loss: 34395.8086 - val_mean_absolute_error: 35.6481
# Epoch 233/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6971.8975 - mean_absolute_error: 28.5188 - val_loss: 33129.8477 - val_mean_absolute_error: 35.6460
# Epoch 234/300
# 19/19 [==============================] - 0s 16ms/step - loss: 6974.6792 - mean_absolute_error: 28.4599 - val_loss: 33586.0781 - val_mean_absolute_error: 35.3101
# Epoch 235/300
# 19/19 [==============================] - 0s 16ms/step - loss: 6794.8281 - mean_absolute_error: 28.0906 - val_loss: 33838.2852 - val_mean_absolute_error: 35.3348
# Epoch 236/300
# 19/19 [==============================] - 0s 21ms/step - loss: 6809.2490 - mean_absolute_error: 28.1555 - val_loss: 33422.6875 - val_mean_absolute_error: 34.9625
# Epoch 237/300
# 19/19 [==============================] - 0s 19ms/step - loss: 6732.9390 - mean_absolute_error: 27.9406 - val_loss: 33438.9141 - val_mean_absolute_error: 35.0820
# Epoch 238/300
# 19/19 [==============================] - 0s 18ms/step - loss: 6701.3408 - mean_absolute_error: 28.0184 - val_loss: 33534.3555 - val_mean_absolute_error: 35.1419
# Epoch 239/300
# 19/19 [==============================] - 0s 23ms/step - loss: 6645.3936 - mean_absolute_error: 27.5350 - val_loss: 32678.6602 - val_mean_absolute_error: 34.9941
# Epoch 240/300
# 19/19 [==============================] - 0s 21ms/step - loss: 6873.7373 - mean_absolute_error: 28.5512 - val_loss: 33336.9219 - val_mean_absolute_error: 35.7906
# Epoch 241/300
# 19/19 [==============================] - 0s 23ms/step - loss: 6718.4800 - mean_absolute_error: 29.3498 - val_loss: 34111.0742 - val_mean_absolute_error: 36.4648
# Epoch 242/300
# 19/19 [==============================] - 0s 20ms/step - loss: 6732.5308 - mean_absolute_error: 28.2255 - val_loss: 33779.0234 - val_mean_absolute_error: 35.5416
# Epoch 243/300
# 19/19 [==============================] - 0s 22ms/step - loss: 6628.1030 - mean_absolute_error: 27.3155 - val_loss: 33300.3594 - val_mean_absolute_error: 34.5845
# Epoch 244/300
# 19/19 [==============================] - 0s 23ms/step - loss: 6566.4873 - mean_absolute_error: 27.0199 - val_loss: 33166.5664 - val_mean_absolute_error: 34.2437
# Epoch 245/300
# 19/19 [==============================] - 0s 21ms/step - loss: 6636.7349 - mean_absolute_error: 26.8714 - val_loss: 33188.4844 - val_mean_absolute_error: 34.2585
# Epoch 246/300
# 19/19 [==============================] - 0s 21ms/step - loss: 6494.8906 - mean_absolute_error: 27.0000 - val_loss: 33496.2969 - val_mean_absolute_error: 36.8932
# Epoch 247/300
# 19/19 [==============================] - 0s 23ms/step - loss: 7128.6089 - mean_absolute_error: 29.5489 - val_loss: 34192.2227 - val_mean_absolute_error: 35.7774
# Epoch 248/300
# 19/19 [==============================] - 0s 18ms/step - loss: 7650.3228 - mean_absolute_error: 28.4002 - val_loss: 32645.3652 - val_mean_absolute_error: 32.8289
# Epoch 249/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7093.7974 - mean_absolute_error: 26.8010 - val_loss: 32149.0371 - val_mean_absolute_error: 32.2504
# Epoch 250/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6934.5088 - mean_absolute_error: 26.7003 - val_loss: 32285.6973 - val_mean_absolute_error: 32.8316
# Epoch 251/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6891.4004 - mean_absolute_error: 27.2721 - val_loss: 32519.4492 - val_mean_absolute_error: 32.9580
# Epoch 252/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6794.9067 - mean_absolute_error: 27.1670 - val_loss: 32540.8105 - val_mean_absolute_error: 33.4072
# Epoch 253/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6652.4014 - mean_absolute_error: 26.9356 - val_loss: 32612.3984 - val_mean_absolute_error: 33.8325
# Epoch 254/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6654.4546 - mean_absolute_error: 27.1267 - val_loss: 32760.3652 - val_mean_absolute_error: 34.5144
# Epoch 255/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6645.0977 - mean_absolute_error: 27.2930 - val_loss: 33117.3516 - val_mean_absolute_error: 36.0153
# Epoch 256/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7393.0415 - mean_absolute_error: 29.9725 - val_loss: 36143.1836 - val_mean_absolute_error: 39.0359
# Epoch 257/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7871.9946 - mean_absolute_error: 30.4210 - val_loss: 34394.5391 - val_mean_absolute_error: 38.0609
# Epoch 258/300
# 19/19 [==============================] - 0s 15ms/step - loss: 7301.3677 - mean_absolute_error: 28.9549 - val_loss: 34068.7383 - val_mean_absolute_error: 35.9117
# Epoch 259/300
# 19/19 [==============================] - 0s 14ms/step - loss: 7052.3813 - mean_absolute_error: 27.9816 - val_loss: 33888.0430 - val_mean_absolute_error: 35.6440
# Epoch 260/300
# 19/19 [==============================] - 0s 13ms/step - loss: 7006.0889 - mean_absolute_error: 27.9309 - val_loss: 33680.6758 - val_mean_absolute_error: 35.4114
# Epoch 261/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6935.1597 - mean_absolute_error: 27.8207 - val_loss: 33893.9023 - val_mean_absolute_error: 35.6766
# Epoch 262/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6873.7417 - mean_absolute_error: 27.5942 - val_loss: 33822.3008 - val_mean_absolute_error: 35.4057
# Epoch 263/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6838.0010 - mean_absolute_error: 27.6070 - val_loss: 33735.2383 - val_mean_absolute_error: 35.4388
# Epoch 264/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6754.0952 - mean_absolute_error: 27.5199 - val_loss: 33722.4766 - val_mean_absolute_error: 35.4551
# Epoch 265/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6709.8525 - mean_absolute_error: 27.5225 - val_loss: 33674.6914 - val_mean_absolute_error: 35.3755
# Epoch 266/300
# 19/19 [==============================] - 0s 16ms/step - loss: 6668.3872 - mean_absolute_error: 27.2887 - val_loss: 33587.4453 - val_mean_absolute_error: 35.3091
# Epoch 267/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6641.7520 - mean_absolute_error: 27.2843 - val_loss: 33588.5039 - val_mean_absolute_error: 35.3030
# Epoch 268/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6590.5210 - mean_absolute_error: 27.2156 - val_loss: 33638.6445 - val_mean_absolute_error: 35.4137
# Epoch 269/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6569.1826 - mean_absolute_error: 27.1659 - val_loss: 33579.6992 - val_mean_absolute_error: 35.3409
# Epoch 270/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6529.4692 - mean_absolute_error: 27.1014 - val_loss: 33543.1914 - val_mean_absolute_error: 35.3568
# Epoch 271/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6489.1567 - mean_absolute_error: 27.0060 - val_loss: 33582.6680 - val_mean_absolute_error: 35.4585
# Epoch 272/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6467.8936 - mean_absolute_error: 26.9694 - val_loss: 33574.3945 - val_mean_absolute_error: 35.4640
# Epoch 273/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6419.7144 - mean_absolute_error: 26.9446 - val_loss: 33670.9492 - val_mean_absolute_error: 35.8243
# Epoch 274/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6400.4639 - mean_absolute_error: 26.9368 - val_loss: 33724.5820 - val_mean_absolute_error: 35.8237
# Epoch 275/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6330.1704 - mean_absolute_error: 26.8270 - val_loss: 33667.5703 - val_mean_absolute_error: 35.7901
# Epoch 276/300
# 19/19 [==============================] - 0s 16ms/step - loss: 6268.5762 - mean_absolute_error: 26.7453 - val_loss: 33631.6289 - val_mean_absolute_error: 35.8191
# Epoch 277/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6245.3140 - mean_absolute_error: 26.7989 - val_loss: 33565.4180 - val_mean_absolute_error: 35.8988
# Epoch 278/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6197.0850 - mean_absolute_error: 26.7560 - val_loss: 33699.3594 - val_mean_absolute_error: 36.0129
# Epoch 279/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6195.2905 - mean_absolute_error: 26.6805 - val_loss: 33623.3906 - val_mean_absolute_error: 35.8463
# Epoch 280/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6114.2700 - mean_absolute_error: 26.6345 - val_loss: 33590.5273 - val_mean_absolute_error: 35.8964
# Epoch 281/300
# 19/19 [==============================] - 0s 14ms/step - loss: 6072.1270 - mean_absolute_error: 26.6090 - val_loss: 33639.4219 - val_mean_absolute_error: 35.7993
# Epoch 282/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6036.2920 - mean_absolute_error: 26.5108 - val_loss: 33523.9766 - val_mean_absolute_error: 35.7953
# Epoch 283/300
# 19/19 [==============================] - 0s 13ms/step - loss: 5981.3130 - mean_absolute_error: 26.4431 - val_loss: 33638.6172 - val_mean_absolute_error: 35.8476
# Epoch 284/300
# 19/19 [==============================] - 0s 15ms/step - loss: 6027.2109 - mean_absolute_error: 26.6023 - val_loss: 33603.0664 - val_mean_absolute_error: 35.9158
# Epoch 285/300
# 19/19 [==============================] - 0s 15ms/step - loss: 10350.8633 - mean_absolute_error: 29.8922 - val_loss: 35540.9453 - val_mean_absolute_error: 40.9603
# Epoch 286/300
# 19/19 [==============================] - 0s 20ms/step - loss: 11254.5928 - mean_absolute_error: 33.4093 - val_loss: 32627.1777 - val_mean_absolute_error: 36.6831
# Epoch 287/300
# 19/19 [==============================] - 0s 23ms/step - loss: 10059.4893 - mean_absolute_error: 30.5035 - val_loss: 32365.0586 - val_mean_absolute_error: 35.5019
# Epoch 288/300
# 19/19 [==============================] - 0s 19ms/step - loss: 9279.5146 - mean_absolute_error: 30.7901 - val_loss: 31699.8867 - val_mean_absolute_error: 38.4700
# Epoch 289/300
# 19/19 [==============================] - 0s 21ms/step - loss: 8015.8477 - mean_absolute_error: 30.4381 - val_loss: 32029.8047 - val_mean_absolute_error: 37.4002
# Epoch 290/300
# 19/19 [==============================] - 0s 23ms/step - loss: 7868.5327 - mean_absolute_error: 30.1485 - val_loss: 32318.6387 - val_mean_absolute_error: 38.2283
# Epoch 291/300
# 19/19 [==============================] - 0s 26ms/step - loss: 7629.4829 - mean_absolute_error: 30.5506 - val_loss: 32598.8867 - val_mean_absolute_error: 38.8172
# Epoch 292/300
# 19/19 [==============================] - 0s 23ms/step - loss: 7450.8535 - mean_absolute_error: 30.5434 - val_loss: 32601.7500 - val_mean_absolute_error: 38.8738
# Epoch 293/300
# 19/19 [==============================] - 0s 20ms/step - loss: 7441.8057 - mean_absolute_error: 30.6643 - val_loss: 32827.1406 - val_mean_absolute_error: 39.0715
# Epoch 294/300
# 19/19 [==============================] - 0s 19ms/step - loss: 7282.6729 - mean_absolute_error: 30.6030 - val_loss: 32990.9102 - val_mean_absolute_error: 39.3549
# Epoch 295/300
# 19/19 [==============================] - 0s 21ms/step - loss: 7144.5767 - mean_absolute_error: 30.5532 - val_loss: 33187.2188 - val_mean_absolute_error: 39.3922
# Epoch 296/300
# 19/19 [==============================] - 0s 21ms/step - loss: 7286.0835 - mean_absolute_error: 31.2255 - val_loss: 33078.6211 - val_mean_absolute_error: 40.8115
# Epoch 297/300
# 19/19 [==============================] - 0s 19ms/step - loss: 7575.9727 - mean_absolute_error: 33.0243 - val_loss: 36347.3594 - val_mean_absolute_error: 43.6819
# Epoch 298/300
# 19/19 [==============================] - 0s 20ms/step - loss: 7662.6470 - mean_absolute_error: 32.9180 - val_loss: 32944.7891 - val_mean_absolute_error: 41.1113
# Epoch 299/300
# 19/19 [==============================] - 0s 17ms/step - loss: 7038.6357 - mean_absolute_error: 32.2727 - val_loss: 33408.2148 - val_mean_absolute_error: 40.1438
# Epoch 300/300
# 19/19 [==============================] - 0s 13ms/step - loss: 6840.8706 - mean_absolute_error: 31.1443 - val_loss: 33541.1562 - val_mean_absolute_error: 40.1474

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss', linewidth=1,color='green')
    plt.plot(epochs, val_loss, 'r', label='Validation loss', linewidth=1,color='purple')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
import pickle

# Save history to a file
with open('history_lstm_km5_others.pkl', 'wb') as file:
    pickle.dump(history, file)

with open('model_lstm_km5_others.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
import pickle

# Load history from file
with open('history_lstm_km5_others.pkl', 'rb') as file:
    history = pickle.load(file)

with open('model_lstm_km5_others.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
plot_train_history(history,
                   'Training and validation loss')
# Out:
# <ipython-input-87-6b1627954cc9>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'b', label='Training loss', linewidth=1,color='green')
# <ipython-input-87-6b1627954cc9>:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'r', label='Validation loss', linewidth=1,color='purple')

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Eğitim kayıpları', linewidth=1,color='green')
    plt.plot(epochs, val_loss, 'r', label='Doğrulama kayıpları', linewidth=1,color='purple')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(history,
                   'k=5, Diğer Kümeler, Eğitim ve Doğrulama Kayıpları')
# Out:
# <ipython-input-103-0bab22136887>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'b', label='Eğitim kayıpları', linewidth=1,color='green')
# <ipython-input-103-0bab22136887>:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'r', label='Doğrulama kayıpları', linewidth=1,color='purple')

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 20/20 [==============================] - 0s 4ms/step

# %%
#y_pred

# %%
#y_test

# %%
plt.figure(figsize=(6,3))


plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("PJM 2022 24-hour ahead predictions")

hour= 24
n_day = 365
plot_day = hour*n_day

plt.plot(y_pred[:,-1], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test[:, -1], label='True', linewidth=1,color='purple')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği-Diğer")

hour= 24
n_day = 365
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
errors = y_pred- y_test
mse = np.square(errors).mean()
rmse = np.sqrt(mse)
mae = np.abs(errors).mean()

print('Mean Absolute Error: {:.2f}'.format(mae))
print('Root Mean Square Error: {:.2f}'.format(rmse))
print('R2 Score: ', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 34.59
# Root Mean Square Error: 98.44
# R2 Score:  0.6701808789918633

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("PJM 2022 24-hour ahead predictions for '30' days")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 30 Günlük-Diğer")

hour= 24
n_day = 30
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 5 Günlük-Diğer")

hour= 24
n_day = 5
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("PJM 2022 24-hour ahead predictions for '5' days")

hour= 24
n_day = 5
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Zaman(saat)')
plt.ylabel('LMP($/MWh)')
plt.title("LSTM-PJM 2022-2023 Haziran 24 Saat İlerisi İçin Tahmin Grafiği, 1 Günlük-Diğer")

hour= 24
n_day = 1
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Tahmin', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='Gerçek', linewidth=1,color='purple')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
# Reshape the y_pred and y_test arrays to have shape (batch_size,)
y_pred_resized = y_pred[:,-1]
y_test_resized = y_test[:,-1]
plt.xlabel('Time(hours)')
plt.ylabel('LMP($/MWh)')
plt.title("PJM 2022 24-hour ahead predictions for 1 Day")

hour= 24
n_day = 1
plot_day = hour*n_day

plt.plot(y_pred_resized[0:plot_day], label='Prediction', linestyle='dotted',color='green')
plt.plot(y_test_resized[0:plot_day], label='True', linewidth=1,color='purple')

plt.legend()
plt.show()
